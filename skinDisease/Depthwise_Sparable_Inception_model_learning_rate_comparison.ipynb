# %%
import tensorflow as tf
from keras.layers import Conv2D,MaxPool2D,SeparableConv2D,DepthwiseConv2D,MaxPooling2D,concatenate,AveragePooling2D,GlobalAveragePooling2D,Dropout,Dense,BatchNormalization,Activation,Flatten
from tensorflow.keras.layers import Conv2D,MaxPool2D,SeparableConv2D,DepthwiseConv2D,MaxPooling2D,concatenate,AveragePooling2D,GlobalAveragePooling2D,Dropout,Dense,BatchNormalization,Activation,Flatten
NUM_CLASSES=7

def DepthwiseSeparableConv2D(x, filters, kernel_size, strides, padding):
    x=SeparableConv2D(filters=filters,kernel_size=kernel_size,strides=strides,padding=padding)(x)
    x=BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def BasicConv2D(x, filters, kernel_size, strides, padding):
    x=Conv2D(filters=filters,kernel_size=kernel_size,strides=strides,padding=padding)(x)
    x=BatchNormalization()(x)
    x = Activation('relu')(x)
    return x
def inception_block_A(x):
    # Branch 1: Average Pooling -> 1x1 Conv
    branch1 = AveragePooling2D(pool_size=(3, 3), strides=(1, 1), padding='same')(x)
    branch1 = BasicConv2D(branch1, filters=96,kernel_size=(1, 1),strides=1,padding="same")

    # Branch 2: 1x1 Conv
    branch2 = BasicConv2D(x,filters=96,kernel_size=(1, 1),strides=1,padding="same")

    # Branch 3: 1x1 Conv -> 3x3 Conv
    branch3 = BasicConv2D(x,filters=96,kernel_size=(3, 3),strides=1,padding="same")
    branch3 = DepthwiseSeparableConv2D(branch3, filters=96, kernel_size=(3, 3), strides=1, padding="same")

    # Branch 4: 1x1 Conv -> 3x3 Conv -> 3x3 Conv
    branch4 = BasicConv2D(x,filters=64,kernel_size=(1, 1),strides=1,padding="same")
    branch4 = DepthwiseSeparableConv2D(branch4, filters=96, kernel_size=(3, 3), strides=1, padding="same")
    branch4 = DepthwiseSeparableConv2D(branch4, filters=96, kernel_size=(3, 3), strides=1, padding="same")

    # Concatenating all the branches
    output = concatenate([branch1, branch2, branch3, branch4], axis=-1)
    return output

def inception_block_B(x):
    # Branch 1: Average Pooling -> 1x1 Conv
    branch1 = AveragePooling2D(pool_size=(3, 3), strides=(1, 1), padding='same')
    branch1 = BasicConv2D(x,filters=128,kernel_size=(1, 1),strides=1,padding="same")

    # Branch 2: 1x1 Conv
    branch2 = BasicConv2D(x,filters=384,kernel_size=(1, 1),strides=1,padding="same")

    # Branch 3: 1x1 Conv -> 1x7 Conv -> 7x1 Conv
    branch3 = BasicConv2D(x,filters=192,kernel_size=(1, 1),strides=1,padding="same")
    branch3 = DepthwiseSeparableConv2D(branch3, filters=224, kernel_size=(1, 7), strides=1, padding="same")
    branch3 = DepthwiseSeparableConv2D(branch3,filters=256,kernel_size=(7, 1),strides=1,padding="same")

    # Branch 4: 1x1 Conv -> 7x1 Conv -> 1x7 Conv -> 7x1 Conv -> 1x7 Conv
    branch4 = BasicConv2D(x,filters=192,kernel_size=(1, 1),strides=1,padding="same")
    branch4 = DepthwiseSeparableConv2D(branch4,filters=192,kernel_size=(1, 7),strides=1,padding="same")
    branch4 = DepthwiseSeparableConv2D(branch4,filters=224,kernel_size=(7, 1),strides=1,padding="same")
    branch4 = DepthwiseSeparableConv2D(branch4,filters=224,kernel_size=(1, 7),strides=1,padding="same")
    branch4 = DepthwiseSeparableConv2D(branch4,filters=256,kernel_size=(7, 1),strides=1,padding="same")

    # Concatenating all the branches
    output = concatenate([branch1, branch2, branch3, branch4], axis=-1)
    return output

def inception_block_C(x):
    # Branch 1: Average Pooling -> 1x1 Conv
    branch1 = AveragePooling2D(pool_size=(3, 3), strides=(1, 1), padding='same')(x)
    branch1 = BasicConv2D(branch1,filters=256,kernel_size=(1, 1),strides=1,padding="same")

    # Branch 2: 1x1 Conv
    branch2 = BasicConv2D(x,filters=256,kernel_size=(1, 1),strides=1,padding="same")

    # Branch 3: 1x1 Conv -> 1x3 and 3x1 Conv
    branch3 = BasicConv2D(x,filters=384,kernel_size=(1, 1),strides=1,padding="same")
    branch3a = DepthwiseSeparableConv2D(branch3,filters=256,kernel_size=(1, 3),strides=1,padding="same")
    branch3b = DepthwiseSeparableConv2D(branch3,filters=256,kernel_size=(3, 1),strides=1,padding="same")
    branch3 = concatenate([branch3a, branch3b], axis=-1)

    # Branch 4: 1x1 Conv -> 3x3 Conv -> 1x3 and 3x1 Conv
    branch4 = BasicConv2D(x,filters=384,kernel_size=(1, 1),strides=1,padding="same")
    branch4 = DepthwiseSeparableConv2D(branch4,filters=448,kernel_size=(1, 3),strides=1,padding="same")
    branch4 = DepthwiseSeparableConv2D(branch4,filters=512,kernel_size=(3, 1),strides=1,padding="same")
    branch4a = DepthwiseSeparableConv2D(branch4,filters=256,kernel_size=(3, 1),strides=1,padding="same")
    branch4b = DepthwiseSeparableConv2D(branch4,filters=256,kernel_size=(1, 3),strides=1,padding="same")
    branch4 = concatenate([branch4a, branch4b], axis=-1)

    # Concatenating all the branches
    output = concatenate([branch1, branch2, branch3, branch4], axis=-1)
    return output
def reduction_A(x):
    # Branch 1: Max Pooling
    branch1 = MaxPooling2D(3, strides=2, padding='valid')(x)

    # Branch 2: 3x3 Conv

    branch2 = BasicConv2D(x, filters=384,kernel_size=(3, 3),strides=2,padding="valid")

    # Branch 3: 1x1 Conv -> 3x3 Conv -> 3x3 Conv

    branch3 = BasicConv2D(x, filters=192,kernel_size=(1, 1),strides=1,padding="same")
    branch3 = BasicConv2D(branch3, filters=224,kernel_size=(3, 3),strides=1,padding="same")
    branch3 = BasicConv2D(branch3, filters=256,kernel_size=(3, 3),strides=2,padding="valid")

    # Concatenating all the branches
    output = concatenate([branch1, branch2, branch3], axis=-1)
    return output
def reduction_B(x):
    # Branch 1: Max Pooling
    branch1 = MaxPooling2D(3, strides=2)(x)

    # Branch 2: 1x1 Conv -> 3x3 Conv
    branch2 = BasicConv2D(x,filters=192,kernel_size=(1, 1),strides=1,padding="same")
    branch2 = BasicConv2D(branch2,filters=192,kernel_size=(3, 3),strides=2,padding="valid")

    # Branch 3: 1x1 Conv -> 1x7 Conv -> 7x1 Conv -> 3x3 Conv
    branch3 = BasicConv2D(x,filters=256,kernel_size=(1, 1),strides=1,padding="same")
    branch3 = BasicConv2D(branch3,filters=256,kernel_size=(1, 7),strides=1,padding="same")
    branch3 = BasicConv2D(branch3,filters=320,kernel_size=(7, 1),strides=1,padding="same")
    branch3 = BasicConv2D(branch3,filters=320,kernel_size=(3, 3),strides=2,padding="valid")

    # Concatenating all the branches
    output = concatenate([branch1, branch2, branch3], axis=-1)
    return output


def Stem(x):
    # Conv 3x3
    x = BasicConv2D(x,filters=32,kernel_size=(3, 3),strides=2,padding="valid")
    x = BasicConv2D(x,filters=32,kernel_size=(3, 3),strides=1,padding="valid")
    x = BasicConv2D(x,filters=64,kernel_size=(3, 3),strides=1,padding="same")

    # Max Pool and Conv
    branch1 = MaxPooling2D((3, 3), strides=2, padding='valid')(x)
    branch2 = BasicConv2D(x,filters=96,kernel_size=(3, 3),strides=2,padding="valid")
    x = concatenate([branch1, branch2], axis=-1)

    # Two parallel branches
    branch1 = BasicConv2D(x, filters=64,kernel_size=(1, 1),strides=1,padding="same")
    branch1 = BasicConv2D(branch1,filters=96,kernel_size=(3, 3),strides=1,padding="valid")

    branch2 = BasicConv2D(x, filters=64,kernel_size=(1, 1),strides=1,padding="same")
    branch2 = BasicConv2D(branch2, filters=64,kernel_size=(7, 1),strides=1,padding="same")
    branch2 = BasicConv2D(branch2,filters=64,kernel_size=(1, 7),strides=1,padding="same")
    branch2 = BasicConv2D(branch2,filters=96,kernel_size=(3, 3),strides=1,padding="valid")

    x = concatenate([branch1, branch2], axis=-1)
    branch1=BasicConv2D(x,filters=192,kernel_size=(3, 3),strides=2,padding="valid")
    branch2=MaxPool2D(pool_size=(3, 3),strides=2,padding="valid")(x)
    x=concatenate([branch1, branch2], axis=-1)


    return x
def DS_inception_Model(x):
    x=Stem(x)
    x=inception_block_A(x)
    x=reduction_A(x)
    x=inception_block_B(x)
    x=reduction_B(x)
    x=inception_block_C(x)
    x = AveragePooling2D(pool_size=(5,5))(x)
    x = Dropout(0.2)(x)
    x= Flatten()(x)
    x= Dense(NUM_CLASSES, activation='softmax')(x)
    return x

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Extracting data from the history object
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    # Plotting training and validation accuracy
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, label='Training Accuracy')
    plt.plot(epochs, val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plotting training and validation loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, label='Training Loss')
    plt.plot(epochs, val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc


def evaluate_model(model, data_path, target_size=(299, 299), batch_size=128):
    datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
    dataset = datagen.flow_from_directory(
        data_path,
        target_size=target_size,
        batch_size=batch_size,
        shuffle=False
    )

    Y_pred = model.predict(dataset)
    y_pred = np.argmax(Y_pred, axis=1)
    y_true = dataset.classes
    class_labels = list(dataset.class_indices.keys())

    conf_matrix = confusion_matrix(y_true, y_pred)
    print('Confusion Matrix:')
    print(conf_matrix)

    conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

    class_report = classification_report(y_true, y_pred, target_names=class_labels)
    print('Classification Report:')
    print(class_report)

    n_classes = Y_pred.shape[1]
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_true == i, Y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    plt.figure(figsize=(10, 8))
    for i, label in enumerate(class_labels):
        plt.plot(fpr[i], tpr[i], lw=2, label='{} (area = {:.2f})'.format(label, roc_auc[i]))

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic for multi-class')
    plt.legend(loc="lower right")
    plt.show()

    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix_normalized, annot=conf_matrix, fmt='d', cmap='Blues',
                xticklabels=class_labels, yticklabels=class_labels)
    plt.title('Confusion Matrix Heatmap')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

# %%
import tensorflow as tf
import os
import pandas as pd
import numpy as np
import datetime
from tensorflow.keras.callbacks import TensorBoard, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.optimizers import Adam

train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,  # Increased rotation range
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,  # Added shear transformation
    zoom_range=0.2,   # Added zoom
    horizontal_flip=True,
    fill_mode='nearest'
)

valid_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

train_dataset = train_datagen.flow_from_directory(
    'HAM10000/train',
    target_size=(299, 299),
    batch_size=128
)

validation_dataset = valid_datagen.flow_from_directory(
    'HAM10000/val',
    target_size=(299, 299),
    batch_size=128
)
# Out:
# Found 8013 images belonging to 7 classes.
# Found 1001 images belonging to 7 classes.

# %%
import tensorflow as tf
import os
import pandas as pd
import numpy as np
import datetime
from tensorflow.keras.callbacks import TensorBoard, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.optimizers import Adam

# Load data
inputs=tf.keras.Input(shape=(299, 299, 3))
outputs=DS_inception_Model(inputs)
model=tf.keras.Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 149, 149, 32  896         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 149, 149, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 149, 149, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 147, 147, 32  9248        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 147, 147, 32  128        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 147, 147, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 147, 147, 64  18496       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 147, 147, 64  256        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 147, 147, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 73, 73, 96)   55392       ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 73, 73, 96)  384         ['conv2d_3[0][0]']
#  rmalization)
#
#  max_pooling2d (MaxPooling2D)   (None, 73, 73, 64)   0           ['activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 73, 73, 96)   0           ['batch_normalization_3[0][0]']
#
#  concatenate (Concatenate)      (None, 73, 73, 160)  0           ['max_pooling2d[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 73, 73, 64)   10304       ['concatenate[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 73, 73, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 73, 73, 64)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 73, 73, 64)   28736       ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 73, 73, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 73, 73, 64)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 73, 73, 64)   10304       ['concatenate[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 73, 73, 64)   28736       ['activation_7[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 73, 73, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  batch_normalization_8 (BatchNo  (None, 73, 73, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 73, 73, 64)   0           ['batch_normalization_4[0][0]']
#
#  activation_8 (Activation)      (None, 73, 73, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 71, 71, 96)   55392       ['activation_4[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 71, 71, 96)   55392       ['activation_8[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 71, 71, 96)  384         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 71, 71, 96)  384         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 71, 71, 96)   0           ['batch_normalization_5[0][0]']
#
#  activation_9 (Activation)      (None, 71, 71, 96)   0           ['batch_normalization_9[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 71, 71, 192)  0           ['activation_5[0][0]',
#                                                                   'activation_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 35, 35, 192)  331968      ['concatenate_1[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 35, 35, 192)  768        ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 35, 35, 192)  0           ['batch_normalization_10[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0          ['concatenate_1[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 35, 35, 384)  0           ['activation_10[0][0]',
#                                                                   'max_pooling2d_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 35, 35, 64)   24640       ['concatenate_2[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 35, 35, 64)  256         ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 35, 35, 96)   331872      ['concatenate_2[0][0]']
#
#  separable_conv2d_1 (SeparableC  (None, 35, 35, 96)  6816        ['activation_15[0][0]']
#  onv2D)
#
#  batch_normalization_13 (BatchN  (None, 35, 35, 96)  384         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 35, 35, 96)  384         ['separable_conv2d_1[0][0]']
#  ormalization)
#
#  average_pooling2d (AveragePool  (None, 35, 35, 384)  0          ['concatenate_2[0][0]']
#  ing2D)
#
#  activation_13 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 35, 35, 96)   36960       ['average_pooling2d[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 35, 35, 96)   36960       ['concatenate_2[0][0]']
#
#  separable_conv2d (SeparableCon  (None, 35, 35, 96)  10176       ['activation_13[0][0]']
#  v2D)
#
#  separable_conv2d_2 (SeparableC  (None, 35, 35, 96)  10176       ['activation_16[0][0]']
#  onv2D)
#
#  batch_normalization_11 (BatchN  (None, 35, 35, 96)  384         ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_12 (BatchN  (None, 35, 35, 96)  384         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 35, 35, 96)  384         ['separable_conv2d[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 35, 35, 96)  384         ['separable_conv2d_2[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_11[0][0]']
#
#  activation_12 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_17[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 35, 35, 384)  0           ['activation_11[0][0]',
#                                                                   'activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 35, 35, 192)  73920       ['concatenate_3[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 35, 35, 192)  768        ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 35, 35, 192)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 35, 35, 224)  387296      ['activation_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 35, 35, 224)  896        ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 35, 35, 224)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 17, 17, 384)  1327488     ['concatenate_3[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 17, 17, 256)  516352      ['activation_20[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 17, 17, 384)  1536       ['conv2d_15[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 17, 17, 256)  1024       ['conv2d_18[0][0]']
#  ormalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 384)  0          ['concatenate_3[0][0]']
#
#  activation_18 (Activation)     (None, 17, 17, 384)  0           ['batch_normalization_18[0][0]']
#
#  activation_21 (Activation)     (None, 17, 17, 256)  0           ['batch_normalization_21[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 17, 17, 1024  0           ['max_pooling2d_2[0][0]',
#                                 )                                 'activation_18[0][0]',
#                                                                   'activation_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 17, 17, 192)  196800      ['concatenate_4[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 17, 17, 192)  768        ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_27[0][0]']
#
#  separable_conv2d_5 (SeparableC  (None, 17, 17, 192)  38400      ['activation_27[0][0]']
#  onv2D)
#
#  batch_normalization_28 (BatchN  (None, 17, 17, 192)  768        ['separable_conv2d_5[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 17, 17, 192)  196800      ['concatenate_4[0][0]']
#
#  separable_conv2d_6 (SeparableC  (None, 17, 17, 224)  44576      ['activation_28[0][0]']
#  onv2D)
#
#  batch_normalization_24 (BatchN  (None, 17, 17, 192)  768        ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 17, 17, 224)  896        ['separable_conv2d_6[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_24[0][0]']
#
#  activation_29 (Activation)     (None, 17, 17, 224)  0           ['batch_normalization_29[0][0]']
#
#  separable_conv2d_3 (SeparableC  (None, 17, 17, 224)  44576      ['activation_24[0][0]']
#  onv2D)
#
#  separable_conv2d_7 (SeparableC  (None, 17, 17, 224)  51968      ['activation_29[0][0]']
#  onv2D)
#
#  batch_normalization_25 (BatchN  (None, 17, 17, 224)  896        ['separable_conv2d_3[0][0]']
#  ormalization)
#
#  batch_normalization_30 (BatchN  (None, 17, 17, 224)  896        ['separable_conv2d_7[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 17, 17, 224)  0           ['batch_normalization_25[0][0]']
#
#  activation_30 (Activation)     (None, 17, 17, 224)  0           ['batch_normalization_30[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 17, 17, 128)  131200      ['concatenate_4[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 17, 17, 384)  393600      ['concatenate_4[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 17, 17, 256)  59168      ['activation_25[0][0]']
#  onv2D)
#
#  separable_conv2d_8 (SeparableC  (None, 17, 17, 256)  59168      ['activation_30[0][0]']
#  onv2D)
#
#  batch_normalization_22 (BatchN  (None, 17, 17, 128)  512        ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 17, 17, 384)  1536       ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 17, 17, 256)  1024       ['separable_conv2d_4[0][0]']
#  ormalization)
#
#  batch_normalization_31 (BatchN  (None, 17, 17, 256)  1024       ['separable_conv2d_8[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_22[0][0]']
#
#  activation_23 (Activation)     (None, 17, 17, 384)  0           ['batch_normalization_23[0][0]']
#
#  activation_26 (Activation)     (None, 17, 17, 256)  0           ['batch_normalization_26[0][0]']
#
#  activation_31 (Activation)     (None, 17, 17, 256)  0           ['batch_normalization_31[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 17, 17, 1024  0           ['activation_22[0][0]',
#                                 )                                 'activation_23[0][0]',
#                                                                   'activation_26[0][0]',
#                                                                   'activation_31[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 17, 17, 256)  262400      ['concatenate_5[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 17, 17, 256)  1024       ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 17, 17, 256)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 17, 17, 256)  459008      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 17, 17, 256)  1024       ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 17, 17, 256)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 17, 17, 192)  196800      ['concatenate_5[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 17, 17, 320)  573760      ['activation_35[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 17, 17, 192)  768        ['conv2d_23[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 17, 17, 320)  1280       ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_32[0][0]']
#
#  activation_36 (Activation)     (None, 17, 17, 320)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 8, 8, 192)    331968      ['activation_32[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 8, 8, 320)    921920      ['activation_36[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 8, 8, 192)   768         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 8, 8, 320)   1280        ['conv2d_28[0][0]']
#  ormalization)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 1024)  0           ['concatenate_5[0][0]']
#
#  activation_33 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_33[0][0]']
#
#  activation_37 (Activation)     (None, 8, 8, 320)    0           ['batch_normalization_37[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 8, 8, 1536)   0           ['max_pooling2d_3[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_37[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 8, 8, 384)    590208      ['concatenate_6[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 8, 8, 384)   1536        ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_43[0][0]']
#
#  separable_conv2d_11 (Separable  (None, 8, 8, 448)   173632      ['activation_43[0][0]']
#  Conv2D)
#
#  batch_normalization_44 (BatchN  (None, 8, 8, 448)   1792        ['separable_conv2d_11[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 8, 8, 448)    0           ['batch_normalization_44[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 8, 8, 384)    590208      ['concatenate_6[0][0]']
#
#  separable_conv2d_12 (Separable  (None, 8, 8, 512)   231232      ['activation_44[0][0]']
#  Conv2D)
#
#  batch_normalization_40 (BatchN  (None, 8, 8, 384)   1536        ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_45 (BatchN  (None, 8, 8, 512)   2048        ['separable_conv2d_12[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_40[0][0]']
#
#  activation_45 (Activation)     (None, 8, 8, 512)    0           ['batch_normalization_45[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 8, 8, 1536)  0           ['concatenate_6[0][0]']
#  oling2D)
#
#  separable_conv2d_9 (SeparableC  (None, 8, 8, 256)   99712       ['activation_40[0][0]']
#  onv2D)
#
#  separable_conv2d_10 (Separable  (None, 8, 8, 256)   99712       ['activation_40[0][0]']
#  Conv2D)
#
#  separable_conv2d_13 (Separable  (None, 8, 8, 256)   132864      ['activation_45[0][0]']
#  Conv2D)
#
#  separable_conv2d_14 (Separable  (None, 8, 8, 256)   132864      ['activation_45[0][0]']
#  Conv2D)
#
#  conv2d_29 (Conv2D)             (None, 8, 8, 256)    393472      ['average_pooling2d_2[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 8, 8, 256)    393472      ['concatenate_6[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 8, 8, 256)   1024        ['separable_conv2d_9[0][0]']
#  ormalization)
#
#  batch_normalization_42 (BatchN  (None, 8, 8, 256)   1024        ['separable_conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 8, 8, 256)   1024        ['separable_conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 8, 8, 256)   1024        ['separable_conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_29[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_41[0][0]']
#
#  activation_42 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_42[0][0]']
#
#  activation_46 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_46[0][0]']
#
#  activation_47 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_47[0][0]']
#
#  activation_38 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_39[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 8, 8, 512)    0           ['activation_41[0][0]',
#                                                                   'activation_42[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 8, 8, 512)    0           ['activation_46[0][0]',
#                                                                   'activation_47[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 8, 8, 1536)   0           ['activation_38[0][0]',
#                                                                   'activation_39[0][0]',
#                                                                   'concatenate_7[0][0]',
#                                                                   'concatenate_8[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 1, 1, 1536)  0           ['concatenate_9[0][0]']
#  oling2D)
#
#  dropout (Dropout)              (None, 1, 1, 1536)   0           ['average_pooling2d_3[0][0]']
#
#  flatten (Flatten)              (None, 1536)         0           ['dropout[0][0]']
#
#  dense (Dense)                  (None, 7)            10759       ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 10,216,295
# Trainable params: 10,197,031
# Non-trainable params: 19,264
# __________________________________________________________________________________________________

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.1), loss='categorical_crossentropy', metrics=['accuracy'])
# Train the model
history=model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=50,
    verbose=1
)
# Out:
# Epoch 1/50
# 63/63 [==============================] - 88s 1s/step - loss: 1.6713 - accuracy: 0.6572 - val_loss: 2724052.0000 - val_accuracy: 0.6693
# Epoch 2/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.9835 - accuracy: 0.6688 - val_loss: 286.1648 - val_accuracy: 0.6693
# Epoch 3/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.9396 - accuracy: 0.6674 - val_loss: 7.0077 - val_accuracy: 0.6703
# Epoch 4/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.9193 - accuracy: 0.6640 - val_loss: 1.3358 - val_accuracy: 0.6623
# Epoch 5/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.8963 - accuracy: 0.6733 - val_loss: 1.4265 - val_accuracy: 0.4935
# Epoch 6/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.8757 - accuracy: 0.6794 - val_loss: 1.1604 - val_accuracy: 0.6134
# Epoch 7/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.8735 - accuracy: 0.6788 - val_loss: 1.6730 - val_accuracy: 0.6623
# Epoch 8/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.8531 - accuracy: 0.6799 - val_loss: 1.4058 - val_accuracy: 0.6633
# Epoch 9/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.8376 - accuracy: 0.6839 - val_loss: 1.0843 - val_accuracy: 0.6144
# Epoch 10/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.8387 - accuracy: 0.6930 - val_loss: 1.3504 - val_accuracy: 0.6723
# Epoch 11/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.8229 - accuracy: 0.6886 - val_loss: 1.3305 - val_accuracy: 0.4086
# Epoch 12/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.8050 - accuracy: 0.6914 - val_loss: 0.9130 - val_accuracy: 0.6633
# Epoch 13/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7947 - accuracy: 0.7039 - val_loss: 1.0501 - val_accuracy: 0.6464
# Epoch 14/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.7879 - accuracy: 0.7002 - val_loss: 0.8966 - val_accuracy: 0.6743
# Epoch 15/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7750 - accuracy: 0.7029 - val_loss: 1.0377 - val_accuracy: 0.6733
# Epoch 16/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7679 - accuracy: 0.7090 - val_loss: 1.3192 - val_accuracy: 0.6014
# Epoch 17/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7560 - accuracy: 0.7136 - val_loss: 0.9838 - val_accuracy: 0.6943
# Epoch 18/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7658 - accuracy: 0.7125 - val_loss: 1.1469 - val_accuracy: 0.6833
# Epoch 19/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7620 - accuracy: 0.7167 - val_loss: 0.9501 - val_accuracy: 0.6523
# Epoch 20/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7457 - accuracy: 0.7158 - val_loss: 0.8595 - val_accuracy: 0.7043
# Epoch 21/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7461 - accuracy: 0.7237 - val_loss: 1.0757 - val_accuracy: 0.6853
# Epoch 22/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.7420 - accuracy: 0.7236 - val_loss: 0.9968 - val_accuracy: 0.6773
# Epoch 23/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7348 - accuracy: 0.7277 - val_loss: 0.9849 - val_accuracy: 0.5754
# Epoch 24/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7421 - accuracy: 0.7254 - val_loss: 1.0351 - val_accuracy: 0.5834
# Epoch 25/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.7400 - accuracy: 0.7230 - val_loss: 1.0799 - val_accuracy: 0.6803
# Epoch 26/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7221 - accuracy: 0.7292 - val_loss: 0.9655 - val_accuracy: 0.6883
# Epoch 27/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.7261 - accuracy: 0.7302 - val_loss: 0.8630 - val_accuracy: 0.6733
# Epoch 28/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7277 - accuracy: 0.7232 - val_loss: 0.7536 - val_accuracy: 0.7243
# Epoch 29/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.7124 - accuracy: 0.7288 - val_loss: 0.8449 - val_accuracy: 0.6533
# Epoch 30/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.7246 - accuracy: 0.7256 - val_loss: 0.9856 - val_accuracy: 0.6513
# Epoch 31/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7182 - accuracy: 0.7338 - val_loss: 1.2588 - val_accuracy: 0.5984
# Epoch 32/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.7027 - accuracy: 0.7314 - val_loss: 0.8516 - val_accuracy: 0.6963
# Epoch 33/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.6999 - accuracy: 0.7383 - val_loss: 1.4936 - val_accuracy: 0.5944
# Epoch 34/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.7190 - accuracy: 0.7334 - val_loss: 0.8489 - val_accuracy: 0.7243
# Epoch 35/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7216 - accuracy: 0.7338 - val_loss: 1.0389 - val_accuracy: 0.6563
# Epoch 36/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7055 - accuracy: 0.7417 - val_loss: 0.8340 - val_accuracy: 0.7053
# Epoch 37/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7105 - accuracy: 0.7372 - val_loss: 1.0099 - val_accuracy: 0.7093
# Epoch 38/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7605 - accuracy: 0.7267 - val_loss: 21053.7598 - val_accuracy: 0.0140
# Epoch 39/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7867 - accuracy: 0.7085 - val_loss: 6.3931 - val_accuracy: 0.6683
# Epoch 40/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.7156 - accuracy: 0.7307 - val_loss: 1.0298 - val_accuracy: 0.5914
# Epoch 41/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7082 - accuracy: 0.7412 - val_loss: 0.8805 - val_accuracy: 0.7043
# Epoch 42/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.7025 - accuracy: 0.7398 - val_loss: 1.0794 - val_accuracy: 0.7143
# Epoch 43/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.6933 - accuracy: 0.7433 - val_loss: 0.8527 - val_accuracy: 0.6963
# Epoch 44/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.6869 - accuracy: 0.7402 - val_loss: 0.7777 - val_accuracy: 0.7253
# Epoch 45/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.6935 - accuracy: 0.7408 - val_loss: 0.8191 - val_accuracy: 0.7273
# Epoch 46/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.6922 - accuracy: 0.7434 - val_loss: 0.9280 - val_accuracy: 0.6833
# Epoch 47/50
# 63/63 [==============================] - 76s 1s/step - loss: 0.6858 - accuracy: 0.7472 - val_loss: 0.7821 - val_accuracy: 0.6823
# Epoch 48/50
# 63/63 [==============================] - 76s 1s/step - loss: 0.6785 - accuracy: 0.7473 - val_loss: 0.8857 - val_accuracy: 0.6743
# Epoch 49/50
# 63/63 [==============================] - 76s 1s/step - loss: 0.6778 - accuracy: 0.7502 - val_loss: 1.2015 - val_accuracy: 0.5744
# Epoch 50/50
# 63/63 [==============================] - 76s 1s/step - loss: 0.6751 - accuracy: 0.7438 - val_loss: 0.8782 - val_accuracy: 0.6933

# %%
plot_training_history(history)

# %%
evaluate_model(model, 'HAM10000/test')
# Out:
# Found 1001 images belonging to 7 classes.
# 8/8 [==============================] - 4s 445ms/step
# Confusion Matrix:
# [[  9   8   3   0   8   4   0]
#  [  2  22   6   0   6  14   2]
#  [  4   6  24   0  44  32   0]
#  [  0   3   0   0   3   5   0]
#  [  1   2   8   0  85  16   0]
#  [  2   5  12   0  93 554   4]
#  [  0   0   0   0   2   0  12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#        akiec       0.50      0.28      0.36        32
#          bcc       0.48      0.42      0.45        52
#          bkl       0.45      0.22      0.29       110
#           df       0.00      0.00      0.00        11
#          mel       0.35      0.76      0.48       112
#           nv       0.89      0.83      0.86       670
#         vasc       0.67      0.86      0.75        14
#
#     accuracy                           0.71      1001
#    macro avg       0.48      0.48      0.46      1001
# weighted avg       0.73      0.71      0.70      1001
# D:\Projects\PythonProjects\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Projects\PythonProjects\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Projects\PythonProjects\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.optimizers import Adam

# Load data
inputs=tf.keras.Input(shape=(299, 299, 3))
outputs=DS_inception_Model(inputs)
model=tf.keras.Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d_33 (Conv2D)             (None, 149, 149, 32  896         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_48 (BatchN  (None, 149, 149, 32  128        ['conv2d_33[0][0]']
#  ormalization)                  )
#
#  activation_48 (Activation)     (None, 149, 149, 32  0           ['batch_normalization_48[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 147, 147, 32  9248        ['activation_48[0][0]']
#                                 )
#
#  batch_normalization_49 (BatchN  (None, 147, 147, 32  128        ['conv2d_34[0][0]']
#  ormalization)                  )
#
#  activation_49 (Activation)     (None, 147, 147, 32  0           ['batch_normalization_49[0][0]']
#                                 )
#
#  conv2d_35 (Conv2D)             (None, 147, 147, 64  18496       ['activation_49[0][0]']
#                                 )
#
#  batch_normalization_50 (BatchN  (None, 147, 147, 64  256        ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  activation_50 (Activation)     (None, 147, 147, 64  0           ['batch_normalization_50[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 73, 73, 96)   55392       ['activation_50[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 73, 73, 96)  384         ['conv2d_36[0][0]']
#  ormalization)
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 73, 73, 64)  0           ['activation_50[0][0]']
#
#  activation_51 (Activation)     (None, 73, 73, 96)   0           ['batch_normalization_51[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 73, 73, 160)  0           ['max_pooling2d_4[0][0]',
#                                                                   'activation_51[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 73, 73, 64)   10304       ['concatenate_10[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 73, 73, 64)  256         ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 73, 73, 64)   0           ['batch_normalization_54[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 73, 73, 64)   28736       ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 73, 73, 64)  256         ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 73, 73, 64)   0           ['batch_normalization_55[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 73, 73, 64)   10304       ['concatenate_10[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 73, 73, 64)   28736       ['activation_55[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 73, 73, 64)  256         ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 73, 73, 64)  256         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 73, 73, 64)   0           ['batch_normalization_52[0][0]']
#
#  activation_56 (Activation)     (None, 73, 73, 64)   0           ['batch_normalization_56[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 71, 71, 96)   55392       ['activation_52[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 71, 71, 96)   55392       ['activation_56[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 71, 71, 96)  384         ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 71, 71, 96)  384         ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 71, 71, 96)   0           ['batch_normalization_53[0][0]']
#
#  activation_57 (Activation)     (None, 71, 71, 96)   0           ['batch_normalization_57[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 71, 71, 192)  0           ['activation_53[0][0]',
#                                                                   'activation_57[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 35, 35, 192)  331968      ['concatenate_11[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 35, 35, 192)  768        ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 35, 35, 192)  0           ['batch_normalization_58[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 35, 35, 192)  0          ['concatenate_11[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 35, 35, 384)  0           ['activation_58[0][0]',
#                                                                   'max_pooling2d_5[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 35, 35, 64)   24640       ['concatenate_12[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 35, 35, 64)  256         ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_63 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_63[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 35, 35, 96)   331872      ['concatenate_12[0][0]']
#
#  separable_conv2d_16 (Separable  (None, 35, 35, 96)  6816        ['activation_63[0][0]']
#  Conv2D)
#
#  batch_normalization_61 (BatchN  (None, 35, 35, 96)  384         ['conv2d_46[0][0]']
#  ormalization)
#
#  batch_normalization_64 (BatchN  (None, 35, 35, 96)  384         ['separable_conv2d_16[0][0]']
#  ormalization)
#
#  average_pooling2d_4 (AveragePo  (None, 35, 35, 384)  0          ['concatenate_12[0][0]']
#  oling2D)
#
#  activation_61 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_61[0][0]']
#
#  activation_64 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_64[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 35, 35, 96)   36960       ['average_pooling2d_4[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 35, 35, 96)   36960       ['concatenate_12[0][0]']
#
#  separable_conv2d_15 (Separable  (None, 35, 35, 96)  10176       ['activation_61[0][0]']
#  Conv2D)
#
#  separable_conv2d_17 (Separable  (None, 35, 35, 96)  10176       ['activation_64[0][0]']
#  Conv2D)
#
#  batch_normalization_59 (BatchN  (None, 35, 35, 96)  384         ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_60 (BatchN  (None, 35, 35, 96)  384         ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_62 (BatchN  (None, 35, 35, 96)  384         ['separable_conv2d_15[0][0]']
#  ormalization)
#
#  batch_normalization_65 (BatchN  (None, 35, 35, 96)  384         ['separable_conv2d_17[0][0]']
#  ormalization)
#
#  activation_59 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_59[0][0]']
#
#  activation_60 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_60[0][0]']
#
#  activation_62 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_62[0][0]']
#
#  activation_65 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_65[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 35, 35, 384)  0           ['activation_59[0][0]',
#                                                                   'activation_60[0][0]',
#                                                                   'activation_62[0][0]',
#                                                                   'activation_65[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 35, 35, 192)  73920       ['concatenate_13[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 35, 35, 192)  768        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_67 (Activation)     (None, 35, 35, 192)  0           ['batch_normalization_67[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 35, 35, 224)  387296      ['activation_67[0][0]']
#
#  batch_normalization_68 (BatchN  (None, 35, 35, 224)  896        ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_68 (Activation)     (None, 35, 35, 224)  0           ['batch_normalization_68[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 17, 17, 384)  1327488     ['concatenate_13[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 17, 17, 256)  516352      ['activation_68[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 17, 17, 384)  1536       ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_69 (BatchN  (None, 17, 17, 256)  1024       ['conv2d_51[0][0]']
#  ormalization)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 17, 17, 384)  0          ['concatenate_13[0][0]']
#
#  activation_66 (Activation)     (None, 17, 17, 384)  0           ['batch_normalization_66[0][0]']
#
#  activation_69 (Activation)     (None, 17, 17, 256)  0           ['batch_normalization_69[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 17, 17, 1024  0           ['max_pooling2d_6[0][0]',
#                                 )                                 'activation_66[0][0]',
#                                                                   'activation_69[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 17, 17, 192)  196800      ['concatenate_14[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 17, 17, 192)  768        ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_75 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_75[0][0]']
#
#  separable_conv2d_20 (Separable  (None, 17, 17, 192)  38400      ['activation_75[0][0]']
#  Conv2D)
#
#  batch_normalization_76 (BatchN  (None, 17, 17, 192)  768        ['separable_conv2d_20[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_76[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 17, 17, 192)  196800      ['concatenate_14[0][0]']
#
#  separable_conv2d_21 (Separable  (None, 17, 17, 224)  44576      ['activation_76[0][0]']
#  Conv2D)
#
#  batch_normalization_72 (BatchN  (None, 17, 17, 192)  768        ['conv2d_54[0][0]']
#  ormalization)
#
#  batch_normalization_77 (BatchN  (None, 17, 17, 224)  896        ['separable_conv2d_21[0][0]']
#  ormalization)
#
#  activation_72 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_72[0][0]']
#
#  activation_77 (Activation)     (None, 17, 17, 224)  0           ['batch_normalization_77[0][0]']
#
#  separable_conv2d_18 (Separable  (None, 17, 17, 224)  44576      ['activation_72[0][0]']
#  Conv2D)
#
#  separable_conv2d_22 (Separable  (None, 17, 17, 224)  51968      ['activation_77[0][0]']
#  Conv2D)
#
#  batch_normalization_73 (BatchN  (None, 17, 17, 224)  896        ['separable_conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_78 (BatchN  (None, 17, 17, 224)  896        ['separable_conv2d_22[0][0]']
#  ormalization)
#
#  activation_73 (Activation)     (None, 17, 17, 224)  0           ['batch_normalization_73[0][0]']
#
#  activation_78 (Activation)     (None, 17, 17, 224)  0           ['batch_normalization_78[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 17, 17, 128)  131200      ['concatenate_14[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 17, 17, 384)  393600      ['concatenate_14[0][0]']
#
#  separable_conv2d_19 (Separable  (None, 17, 17, 256)  59168      ['activation_73[0][0]']
#  Conv2D)
#
#  separable_conv2d_23 (Separable  (None, 17, 17, 256)  59168      ['activation_78[0][0]']
#  Conv2D)
#
#  batch_normalization_70 (BatchN  (None, 17, 17, 128)  512        ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_71 (BatchN  (None, 17, 17, 384)  1536       ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_74 (BatchN  (None, 17, 17, 256)  1024       ['separable_conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_79 (BatchN  (None, 17, 17, 256)  1024       ['separable_conv2d_23[0][0]']
#  ormalization)
#
#  activation_70 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_70[0][0]']
#
#  activation_71 (Activation)     (None, 17, 17, 384)  0           ['batch_normalization_71[0][0]']
#
#  activation_74 (Activation)     (None, 17, 17, 256)  0           ['batch_normalization_74[0][0]']
#
#  activation_79 (Activation)     (None, 17, 17, 256)  0           ['batch_normalization_79[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 17, 17, 1024  0           ['activation_70[0][0]',
#                                 )                                 'activation_71[0][0]',
#                                                                   'activation_74[0][0]',
#                                                                   'activation_79[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 17, 17, 256)  262400      ['concatenate_15[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 17, 17, 256)  1024       ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_82 (Activation)     (None, 17, 17, 256)  0           ['batch_normalization_82[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 17, 17, 256)  459008      ['activation_82[0][0]']
#
#  batch_normalization_83 (BatchN  (None, 17, 17, 256)  1024       ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_83 (Activation)     (None, 17, 17, 256)  0           ['batch_normalization_83[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 17, 17, 192)  196800      ['concatenate_15[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 17, 17, 320)  573760      ['activation_83[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 17, 17, 192)  768        ['conv2d_56[0][0]']
#  ormalization)
#
#  batch_normalization_84 (BatchN  (None, 17, 17, 320)  1280       ['conv2d_60[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_80[0][0]']
#
#  activation_84 (Activation)     (None, 17, 17, 320)  0           ['batch_normalization_84[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 8, 8, 192)    331968      ['activation_80[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 8, 8, 320)    921920      ['activation_84[0][0]']
#
#  batch_normalization_81 (BatchN  (None, 8, 8, 192)   768         ['conv2d_57[0][0]']
#  ormalization)
#
#  batch_normalization_85 (BatchN  (None, 8, 8, 320)   1280        ['conv2d_61[0][0]']
#  ormalization)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 1024)  0           ['concatenate_15[0][0]']
#
#  activation_81 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_81[0][0]']
#
#  activation_85 (Activation)     (None, 8, 8, 320)    0           ['batch_normalization_85[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 8, 8, 1536)   0           ['max_pooling2d_7[0][0]',
#                                                                   'activation_81[0][0]',
#                                                                   'activation_85[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 8, 8, 384)    590208      ['concatenate_16[0][0]']
#
#  batch_normalization_91 (BatchN  (None, 8, 8, 384)   1536        ['conv2d_65[0][0]']
#  ormalization)
#
#  activation_91 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_91[0][0]']
#
#  separable_conv2d_26 (Separable  (None, 8, 8, 448)   173632      ['activation_91[0][0]']
#  Conv2D)
#
#  batch_normalization_92 (BatchN  (None, 8, 8, 448)   1792        ['separable_conv2d_26[0][0]']
#  ormalization)
#
#  activation_92 (Activation)     (None, 8, 8, 448)    0           ['batch_normalization_92[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 8, 8, 384)    590208      ['concatenate_16[0][0]']
#
#  separable_conv2d_27 (Separable  (None, 8, 8, 512)   231232      ['activation_92[0][0]']
#  Conv2D)
#
#  batch_normalization_88 (BatchN  (None, 8, 8, 384)   1536        ['conv2d_64[0][0]']
#  ormalization)
#
#  batch_normalization_93 (BatchN  (None, 8, 8, 512)   2048        ['separable_conv2d_27[0][0]']
#  ormalization)
#
#  activation_88 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_93 (Activation)     (None, 8, 8, 512)    0           ['batch_normalization_93[0][0]']
#
#  average_pooling2d_6 (AveragePo  (None, 8, 8, 1536)  0           ['concatenate_16[0][0]']
#  oling2D)
#
#  separable_conv2d_24 (Separable  (None, 8, 8, 256)   99712       ['activation_88[0][0]']
#  Conv2D)
#
#  separable_conv2d_25 (Separable  (None, 8, 8, 256)   99712       ['activation_88[0][0]']
#  Conv2D)
#
#  separable_conv2d_28 (Separable  (None, 8, 8, 256)   132864      ['activation_93[0][0]']
#  Conv2D)
#
#  separable_conv2d_29 (Separable  (None, 8, 8, 256)   132864      ['activation_93[0][0]']
#  Conv2D)
#
#  conv2d_62 (Conv2D)             (None, 8, 8, 256)    393472      ['average_pooling2d_6[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 8, 8, 256)    393472      ['concatenate_16[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 8, 8, 256)   1024        ['separable_conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_90 (BatchN  (None, 8, 8, 256)   1024        ['separable_conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_94 (BatchN  (None, 8, 8, 256)   1024        ['separable_conv2d_28[0][0]']
#  ormalization)
#
#  batch_normalization_95 (BatchN  (None, 8, 8, 256)   1024        ['separable_conv2d_29[0][0]']
#  ormalization)
#
#  batch_normalization_86 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_62[0][0]']
#  ormalization)
#
#  batch_normalization_87 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_63[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_89[0][0]']
#
#  activation_90 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_90[0][0]']
#
#  activation_94 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_94[0][0]']
#
#  activation_95 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_95[0][0]']
#
#  activation_86 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_86[0][0]']
#
#  activation_87 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_87[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 8, 8, 512)    0           ['activation_89[0][0]',
#                                                                   'activation_90[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 8, 8, 512)    0           ['activation_94[0][0]',
#                                                                   'activation_95[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 8, 8, 1536)   0           ['activation_86[0][0]',
#                                                                   'activation_87[0][0]',
#                                                                   'concatenate_17[0][0]',
#                                                                   'concatenate_18[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 1, 1, 1536)  0           ['concatenate_19[0][0]']
#  oling2D)
#
#  dropout_1 (Dropout)            (None, 1, 1, 1536)   0           ['average_pooling2d_7[0][0]']
#
#  flatten_1 (Flatten)            (None, 1536)         0           ['dropout_1[0][0]']
#
#  dense_1 (Dense)                (None, 7)            10759       ['flatten_1[0][0]']
#
# ==================================================================================================
# Total params: 10,216,295
# Trainable params: 10,197,031
# Non-trainable params: 19,264
# __________________________________________________________________________________________________

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.01), loss='categorical_crossentropy', metrics=['accuracy'])
# Train the model
history=model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=50,
    verbose=1
)
# Out:
# Epoch 1/50
# 63/63 [==============================] - 79s 1s/step - loss: 1.2688 - accuracy: 0.6522 - val_loss: 10503.3281 - val_accuracy: 0.1728
# Epoch 2/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.8955 - accuracy: 0.6783 - val_loss: 1.3707 - val_accuracy: 0.6663
# Epoch 3/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.8437 - accuracy: 0.6910 - val_loss: 2.0440 - val_accuracy: 0.2997
# Epoch 4/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.8028 - accuracy: 0.7045 - val_loss: 1.8924 - val_accuracy: 0.5415
# Epoch 5/50
# 63/63 [==============================] - 76s 1s/step - loss: 0.7870 - accuracy: 0.7120 - val_loss: 4.5996 - val_accuracy: 0.1948
# Epoch 6/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7850 - accuracy: 0.7151 - val_loss: 2.7792 - val_accuracy: 0.2727
# Epoch 7/50
# 63/63 [==============================] - 76s 1s/step - loss: 0.7621 - accuracy: 0.7141 - val_loss: 1.9971 - val_accuracy: 0.3487
# Epoch 8/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7348 - accuracy: 0.7289 - val_loss: 1.9920 - val_accuracy: 0.5135
# Epoch 9/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7222 - accuracy: 0.7296 - val_loss: 1.0808 - val_accuracy: 0.6064
# Epoch 10/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7111 - accuracy: 0.7371 - val_loss: 1.8148 - val_accuracy: 0.5325
# Epoch 11/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7297 - accuracy: 0.7241 - val_loss: 1.1251 - val_accuracy: 0.5784
# Epoch 12/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.6968 - accuracy: 0.7434 - val_loss: 1.3348 - val_accuracy: 0.6214
# Epoch 13/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.6928 - accuracy: 0.7366 - val_loss: 2.4675 - val_accuracy: 0.2777
# Epoch 14/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.6864 - accuracy: 0.7413 - val_loss: 4.9862 - val_accuracy: 0.1538
# Epoch 15/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.6769 - accuracy: 0.7480 - val_loss: 1.2156 - val_accuracy: 0.6064
# Epoch 16/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.6671 - accuracy: 0.7485 - val_loss: 1.0922 - val_accuracy: 0.6094
# Epoch 17/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.6666 - accuracy: 0.7523 - val_loss: 1.1248 - val_accuracy: 0.5994
# Epoch 18/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.6780 - accuracy: 0.7508 - val_loss: 1.5757 - val_accuracy: 0.5335
# Epoch 19/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.6574 - accuracy: 0.7544 - val_loss: 1.0196 - val_accuracy: 0.6074
# Epoch 20/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.6480 - accuracy: 0.7571 - val_loss: 0.9277 - val_accuracy: 0.6364
# Epoch 21/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.6454 - accuracy: 0.7559 - val_loss: 1.0458 - val_accuracy: 0.6394
# Epoch 22/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.6183 - accuracy: 0.7650 - val_loss: 1.4588 - val_accuracy: 0.5724
# Epoch 23/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.6344 - accuracy: 0.7618 - val_loss: 1.4215 - val_accuracy: 0.5844
# Epoch 24/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.6305 - accuracy: 0.7599 - val_loss: 1.1030 - val_accuracy: 0.6344
# Epoch 25/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.6229 - accuracy: 0.7626 - val_loss: 0.8961 - val_accuracy: 0.6983
# Epoch 26/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.6220 - accuracy: 0.7745 - val_loss: 1.0618 - val_accuracy: 0.6404
# Epoch 27/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.6134 - accuracy: 0.7664 - val_loss: 1.1285 - val_accuracy: 0.6503
# Epoch 28/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.6027 - accuracy: 0.7745 - val_loss: 1.0097 - val_accuracy: 0.6823
# Epoch 29/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.5936 - accuracy: 0.7792 - val_loss: 0.8593 - val_accuracy: 0.6883
# Epoch 30/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.5977 - accuracy: 0.7721 - val_loss: 1.0696 - val_accuracy: 0.5984
# Epoch 31/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.5925 - accuracy: 0.7715 - val_loss: 1.0902 - val_accuracy: 0.6633
# Epoch 32/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.5910 - accuracy: 0.7791 - val_loss: 0.9253 - val_accuracy: 0.6803
# Epoch 33/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.5781 - accuracy: 0.7816 - val_loss: 0.9435 - val_accuracy: 0.6613
# Epoch 34/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.5809 - accuracy: 0.7826 - val_loss: 0.8962 - val_accuracy: 0.6833
# Epoch 35/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.5792 - accuracy: 0.7825 - val_loss: 1.2986 - val_accuracy: 0.6184
# Epoch 36/50
# 63/63 [==============================] - 76s 1s/step - loss: 0.5824 - accuracy: 0.7786 - val_loss: 1.5453 - val_accuracy: 0.4895
# Epoch 37/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.5716 - accuracy: 0.7861 - val_loss: 1.2107 - val_accuracy: 0.6933
# Epoch 38/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.5565 - accuracy: 0.7878 - val_loss: 0.6956 - val_accuracy: 0.7622
# Epoch 39/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.5516 - accuracy: 0.7892 - val_loss: 0.7679 - val_accuracy: 0.7013
# Epoch 40/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.5538 - accuracy: 0.7921 - val_loss: 0.7955 - val_accuracy: 0.7283
# Epoch 41/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.5538 - accuracy: 0.7882 - val_loss: 0.8240 - val_accuracy: 0.6923
# Epoch 42/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.5458 - accuracy: 0.7907 - val_loss: 1.0760 - val_accuracy: 0.6903
# Epoch 43/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.5469 - accuracy: 0.7883 - val_loss: 0.9110 - val_accuracy: 0.6673
# Epoch 44/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.5318 - accuracy: 0.7990 - val_loss: 0.9327 - val_accuracy: 0.6773
# Epoch 45/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.5360 - accuracy: 0.7966 - val_loss: 0.6349 - val_accuracy: 0.7622
# Epoch 46/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.5428 - accuracy: 0.7971 - val_loss: 1.1243 - val_accuracy: 0.6394
# Epoch 47/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.5364 - accuracy: 0.7961 - val_loss: 0.8329 - val_accuracy: 0.7273
# Epoch 48/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.5202 - accuracy: 0.8057 - val_loss: 1.0153 - val_accuracy: 0.6823
# Epoch 49/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.5230 - accuracy: 0.8008 - val_loss: 1.0579 - val_accuracy: 0.6933
# Epoch 50/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.5148 - accuracy: 0.8038 - val_loss: 0.7548 - val_accuracy: 0.7443

# %%
plot_training_history(history)

# %%
evaluate_model(model, 'HAM10000/test')
# Out:
# Found 1001 images belonging to 7 classes.
# 8/8 [==============================] - 4s 402ms/step
# Confusion Matrix:
# [[ 16   2   5   0   4   5   0]
#  [  6  22   2   2   3  16   1]
#  [  3   2  42   1  23  39   0]
#  [  3   0   0   2   2   4   0]
#  [  3   2  10   1  66  30   0]
#  [  1   3  20  14  43 586   3]
#  [  0   0   1   0   0   1  12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#        akiec       0.50      0.50      0.50        32
#          bcc       0.71      0.42      0.53        52
#          bkl       0.53      0.38      0.44       110
#           df       0.10      0.18      0.13        11
#          mel       0.47      0.59      0.52       112
#           nv       0.86      0.87      0.87       670
#         vasc       0.75      0.86      0.80        14
#
#     accuracy                           0.75      1001
#    macro avg       0.56      0.54      0.54      1001
# weighted avg       0.75      0.75      0.74      1001

# %%
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.optimizers import Adam

# Load data
inputs=tf.keras.Input(shape=(299, 299, 3))
outputs=DS_inception_Model(inputs)
model=tf.keras.Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d_66 (Conv2D)             (None, 149, 149, 32  896         ['input_3[0][0]']
#                                 )
#
#  batch_normalization_96 (BatchN  (None, 149, 149, 32  128        ['conv2d_66[0][0]']
#  ormalization)                  )
#
#  activation_96 (Activation)     (None, 149, 149, 32  0           ['batch_normalization_96[0][0]']
#                                 )
#
#  conv2d_67 (Conv2D)             (None, 147, 147, 32  9248        ['activation_96[0][0]']
#                                 )
#
#  batch_normalization_97 (BatchN  (None, 147, 147, 32  128        ['conv2d_67[0][0]']
#  ormalization)                  )
#
#  activation_97 (Activation)     (None, 147, 147, 32  0           ['batch_normalization_97[0][0]']
#                                 )
#
#  conv2d_68 (Conv2D)             (None, 147, 147, 64  18496       ['activation_97[0][0]']
#                                 )
#
#  batch_normalization_98 (BatchN  (None, 147, 147, 64  256        ['conv2d_68[0][0]']
#  ormalization)                  )
#
#  activation_98 (Activation)     (None, 147, 147, 64  0           ['batch_normalization_98[0][0]']
#                                 )
#
#  conv2d_69 (Conv2D)             (None, 73, 73, 96)   55392       ['activation_98[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 73, 73, 96)  384         ['conv2d_69[0][0]']
#  ormalization)
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 73, 73, 64)  0           ['activation_98[0][0]']
#
#  activation_99 (Activation)     (None, 73, 73, 96)   0           ['batch_normalization_99[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 73, 73, 160)  0           ['max_pooling2d_8[0][0]',
#                                                                   'activation_99[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 73, 73, 64)   10304       ['concatenate_20[0][0]']
#
#  batch_normalization_102 (Batch  (None, 73, 73, 64)  256         ['conv2d_72[0][0]']
#  Normalization)
#
#  activation_102 (Activation)    (None, 73, 73, 64)   0           ['batch_normalization_102[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 73, 73, 64)   28736       ['activation_102[0][0]']
#
#  batch_normalization_103 (Batch  (None, 73, 73, 64)  256         ['conv2d_73[0][0]']
#  Normalization)
#
#  activation_103 (Activation)    (None, 73, 73, 64)   0           ['batch_normalization_103[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 73, 73, 64)   10304       ['concatenate_20[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 73, 73, 64)   28736       ['activation_103[0][0]']
#
#  batch_normalization_100 (Batch  (None, 73, 73, 64)  256         ['conv2d_70[0][0]']
#  Normalization)
#
#  batch_normalization_104 (Batch  (None, 73, 73, 64)  256         ['conv2d_74[0][0]']
#  Normalization)
#
#  activation_100 (Activation)    (None, 73, 73, 64)   0           ['batch_normalization_100[0][0]']
#
#  activation_104 (Activation)    (None, 73, 73, 64)   0           ['batch_normalization_104[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 71, 71, 96)   55392       ['activation_100[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 71, 71, 96)   55392       ['activation_104[0][0]']
#
#  batch_normalization_101 (Batch  (None, 71, 71, 96)  384         ['conv2d_71[0][0]']
#  Normalization)
#
#  batch_normalization_105 (Batch  (None, 71, 71, 96)  384         ['conv2d_75[0][0]']
#  Normalization)
#
#  activation_101 (Activation)    (None, 71, 71, 96)   0           ['batch_normalization_101[0][0]']
#
#  activation_105 (Activation)    (None, 71, 71, 96)   0           ['batch_normalization_105[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 71, 71, 192)  0           ['activation_101[0][0]',
#                                                                   'activation_105[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 35, 35, 192)  331968      ['concatenate_21[0][0]']
#
#  batch_normalization_106 (Batch  (None, 35, 35, 192)  768        ['conv2d_76[0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (None, 35, 35, 192)  0           ['batch_normalization_106[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 35, 35, 192)  0          ['concatenate_21[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 35, 35, 384)  0           ['activation_106[0][0]',
#                                                                   'max_pooling2d_9[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 35, 35, 64)   24640       ['concatenate_22[0][0]']
#
#  batch_normalization_111 (Batch  (None, 35, 35, 64)  256         ['conv2d_80[0][0]']
#  Normalization)
#
#  activation_111 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_111[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 35, 35, 96)   331872      ['concatenate_22[0][0]']
#
#  separable_conv2d_31 (Separable  (None, 35, 35, 96)  6816        ['activation_111[0][0]']
#  Conv2D)
#
#  batch_normalization_109 (Batch  (None, 35, 35, 96)  384         ['conv2d_79[0][0]']
#  Normalization)
#
#  batch_normalization_112 (Batch  (None, 35, 35, 96)  384         ['separable_conv2d_31[0][0]']
#  Normalization)
#
#  average_pooling2d_8 (AveragePo  (None, 35, 35, 384)  0          ['concatenate_22[0][0]']
#  oling2D)
#
#  activation_109 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_109[0][0]']
#
#  activation_112 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_112[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 35, 35, 96)   36960       ['average_pooling2d_8[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 35, 35, 96)   36960       ['concatenate_22[0][0]']
#
#  separable_conv2d_30 (Separable  (None, 35, 35, 96)  10176       ['activation_109[0][0]']
#  Conv2D)
#
#  separable_conv2d_32 (Separable  (None, 35, 35, 96)  10176       ['activation_112[0][0]']
#  Conv2D)
#
#  batch_normalization_107 (Batch  (None, 35, 35, 96)  384         ['conv2d_77[0][0]']
#  Normalization)
#
#  batch_normalization_108 (Batch  (None, 35, 35, 96)  384         ['conv2d_78[0][0]']
#  Normalization)
#
#  batch_normalization_110 (Batch  (None, 35, 35, 96)  384         ['separable_conv2d_30[0][0]']
#  Normalization)
#
#  batch_normalization_113 (Batch  (None, 35, 35, 96)  384         ['separable_conv2d_32[0][0]']
#  Normalization)
#
#  activation_107 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_107[0][0]']
#
#  activation_108 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_108[0][0]']
#
#  activation_110 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_110[0][0]']
#
#  activation_113 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_113[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 35, 35, 384)  0           ['activation_107[0][0]',
#                                                                   'activation_108[0][0]',
#                                                                   'activation_110[0][0]',
#                                                                   'activation_113[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 35, 35, 192)  73920       ['concatenate_23[0][0]']
#
#  batch_normalization_115 (Batch  (None, 35, 35, 192)  768        ['conv2d_82[0][0]']
#  Normalization)
#
#  activation_115 (Activation)    (None, 35, 35, 192)  0           ['batch_normalization_115[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 35, 35, 224)  387296      ['activation_115[0][0]']
#
#  batch_normalization_116 (Batch  (None, 35, 35, 224)  896        ['conv2d_83[0][0]']
#  Normalization)
#
#  activation_116 (Activation)    (None, 35, 35, 224)  0           ['batch_normalization_116[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 17, 17, 384)  1327488     ['concatenate_23[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 17, 17, 256)  516352      ['activation_116[0][0]']
#
#  batch_normalization_114 (Batch  (None, 17, 17, 384)  1536       ['conv2d_81[0][0]']
#  Normalization)
#
#  batch_normalization_117 (Batch  (None, 17, 17, 256)  1024       ['conv2d_84[0][0]']
#  Normalization)
#
#  max_pooling2d_10 (MaxPooling2D  (None, 17, 17, 384)  0          ['concatenate_23[0][0]']
#  )
#
#  activation_114 (Activation)    (None, 17, 17, 384)  0           ['batch_normalization_114[0][0]']
#
#  activation_117 (Activation)    (None, 17, 17, 256)  0           ['batch_normalization_117[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 17, 17, 1024  0           ['max_pooling2d_10[0][0]',
#                                 )                                 'activation_114[0][0]',
#                                                                   'activation_117[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 17, 17, 192)  196800      ['concatenate_24[0][0]']
#
#  batch_normalization_123 (Batch  (None, 17, 17, 192)  768        ['conv2d_88[0][0]']
#  Normalization)
#
#  activation_123 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_123[0][0]']
#
#  separable_conv2d_35 (Separable  (None, 17, 17, 192)  38400      ['activation_123[0][0]']
#  Conv2D)
#
#  batch_normalization_124 (Batch  (None, 17, 17, 192)  768        ['separable_conv2d_35[0][0]']
#  Normalization)
#
#  activation_124 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_124[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 17, 17, 192)  196800      ['concatenate_24[0][0]']
#
#  separable_conv2d_36 (Separable  (None, 17, 17, 224)  44576      ['activation_124[0][0]']
#  Conv2D)
#
#  batch_normalization_120 (Batch  (None, 17, 17, 192)  768        ['conv2d_87[0][0]']
#  Normalization)
#
#  batch_normalization_125 (Batch  (None, 17, 17, 224)  896        ['separable_conv2d_36[0][0]']
#  Normalization)
#
#  activation_120 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_120[0][0]']
#
#  activation_125 (Activation)    (None, 17, 17, 224)  0           ['batch_normalization_125[0][0]']
#
#  separable_conv2d_33 (Separable  (None, 17, 17, 224)  44576      ['activation_120[0][0]']
#  Conv2D)
#
#  separable_conv2d_37 (Separable  (None, 17, 17, 224)  51968      ['activation_125[0][0]']
#  Conv2D)
#
#  batch_normalization_121 (Batch  (None, 17, 17, 224)  896        ['separable_conv2d_33[0][0]']
#  Normalization)
#
#  batch_normalization_126 (Batch  (None, 17, 17, 224)  896        ['separable_conv2d_37[0][0]']
#  Normalization)
#
#  activation_121 (Activation)    (None, 17, 17, 224)  0           ['batch_normalization_121[0][0]']
#
#  activation_126 (Activation)    (None, 17, 17, 224)  0           ['batch_normalization_126[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 17, 17, 128)  131200      ['concatenate_24[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 17, 17, 384)  393600      ['concatenate_24[0][0]']
#
#  separable_conv2d_34 (Separable  (None, 17, 17, 256)  59168      ['activation_121[0][0]']
#  Conv2D)
#
#  separable_conv2d_38 (Separable  (None, 17, 17, 256)  59168      ['activation_126[0][0]']
#  Conv2D)
#
#  batch_normalization_118 (Batch  (None, 17, 17, 128)  512        ['conv2d_85[0][0]']
#  Normalization)
#
#  batch_normalization_119 (Batch  (None, 17, 17, 384)  1536       ['conv2d_86[0][0]']
#  Normalization)
#
#  batch_normalization_122 (Batch  (None, 17, 17, 256)  1024       ['separable_conv2d_34[0][0]']
#  Normalization)
#
#  batch_normalization_127 (Batch  (None, 17, 17, 256)  1024       ['separable_conv2d_38[0][0]']
#  Normalization)
#
#  activation_118 (Activation)    (None, 17, 17, 128)  0           ['batch_normalization_118[0][0]']
#
#  activation_119 (Activation)    (None, 17, 17, 384)  0           ['batch_normalization_119[0][0]']
#
#  activation_122 (Activation)    (None, 17, 17, 256)  0           ['batch_normalization_122[0][0]']
#
#  activation_127 (Activation)    (None, 17, 17, 256)  0           ['batch_normalization_127[0][0]']
#
#  concatenate_25 (Concatenate)   (None, 17, 17, 1024  0           ['activation_118[0][0]',
#                                 )                                 'activation_119[0][0]',
#                                                                   'activation_122[0][0]',
#                                                                   'activation_127[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 17, 17, 256)  262400      ['concatenate_25[0][0]']
#
#  batch_normalization_130 (Batch  (None, 17, 17, 256)  1024       ['conv2d_91[0][0]']
#  Normalization)
#
#  activation_130 (Activation)    (None, 17, 17, 256)  0           ['batch_normalization_130[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 17, 17, 256)  459008      ['activation_130[0][0]']
#
#  batch_normalization_131 (Batch  (None, 17, 17, 256)  1024       ['conv2d_92[0][0]']
#  Normalization)
#
#  activation_131 (Activation)    (None, 17, 17, 256)  0           ['batch_normalization_131[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 17, 17, 192)  196800      ['concatenate_25[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 17, 17, 320)  573760      ['activation_131[0][0]']
#
#  batch_normalization_128 (Batch  (None, 17, 17, 192)  768        ['conv2d_89[0][0]']
#  Normalization)
#
#  batch_normalization_132 (Batch  (None, 17, 17, 320)  1280       ['conv2d_93[0][0]']
#  Normalization)
#
#  activation_128 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_128[0][0]']
#
#  activation_132 (Activation)    (None, 17, 17, 320)  0           ['batch_normalization_132[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 8, 8, 192)    331968      ['activation_128[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 8, 8, 320)    921920      ['activation_132[0][0]']
#
#  batch_normalization_129 (Batch  (None, 8, 8, 192)   768         ['conv2d_90[0][0]']
#  Normalization)
#
#  batch_normalization_133 (Batch  (None, 8, 8, 320)   1280        ['conv2d_94[0][0]']
#  Normalization)
#
#  max_pooling2d_11 (MaxPooling2D  (None, 8, 8, 1024)  0           ['concatenate_25[0][0]']
#  )
#
#  activation_129 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_129[0][0]']
#
#  activation_133 (Activation)    (None, 8, 8, 320)    0           ['batch_normalization_133[0][0]']
#
#  concatenate_26 (Concatenate)   (None, 8, 8, 1536)   0           ['max_pooling2d_11[0][0]',
#                                                                   'activation_129[0][0]',
#                                                                   'activation_133[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 8, 8, 384)    590208      ['concatenate_26[0][0]']
#
#  batch_normalization_139 (Batch  (None, 8, 8, 384)   1536        ['conv2d_98[0][0]']
#  Normalization)
#
#  activation_139 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_139[0][0]']
#
#  separable_conv2d_41 (Separable  (None, 8, 8, 448)   173632      ['activation_139[0][0]']
#  Conv2D)
#
#  batch_normalization_140 (Batch  (None, 8, 8, 448)   1792        ['separable_conv2d_41[0][0]']
#  Normalization)
#
#  activation_140 (Activation)    (None, 8, 8, 448)    0           ['batch_normalization_140[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 8, 8, 384)    590208      ['concatenate_26[0][0]']
#
#  separable_conv2d_42 (Separable  (None, 8, 8, 512)   231232      ['activation_140[0][0]']
#  Conv2D)
#
#  batch_normalization_136 (Batch  (None, 8, 8, 384)   1536        ['conv2d_97[0][0]']
#  Normalization)
#
#  batch_normalization_141 (Batch  (None, 8, 8, 512)   2048        ['separable_conv2d_42[0][0]']
#  Normalization)
#
#  activation_136 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_136[0][0]']
#
#  activation_141 (Activation)    (None, 8, 8, 512)    0           ['batch_normalization_141[0][0]']
#
#  average_pooling2d_10 (AverageP  (None, 8, 8, 1536)  0           ['concatenate_26[0][0]']
#  ooling2D)
#
#  separable_conv2d_39 (Separable  (None, 8, 8, 256)   99712       ['activation_136[0][0]']
#  Conv2D)
#
#  separable_conv2d_40 (Separable  (None, 8, 8, 256)   99712       ['activation_136[0][0]']
#  Conv2D)
#
#  separable_conv2d_43 (Separable  (None, 8, 8, 256)   132864      ['activation_141[0][0]']
#  Conv2D)
#
#  separable_conv2d_44 (Separable  (None, 8, 8, 256)   132864      ['activation_141[0][0]']
#  Conv2D)
#
#  conv2d_95 (Conv2D)             (None, 8, 8, 256)    393472      ['average_pooling2d_10[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 8, 8, 256)    393472      ['concatenate_26[0][0]']
#
#  batch_normalization_137 (Batch  (None, 8, 8, 256)   1024        ['separable_conv2d_39[0][0]']
#  Normalization)
#
#  batch_normalization_138 (Batch  (None, 8, 8, 256)   1024        ['separable_conv2d_40[0][0]']
#  Normalization)
#
#  batch_normalization_142 (Batch  (None, 8, 8, 256)   1024        ['separable_conv2d_43[0][0]']
#  Normalization)
#
#  batch_normalization_143 (Batch  (None, 8, 8, 256)   1024        ['separable_conv2d_44[0][0]']
#  Normalization)
#
#  batch_normalization_134 (Batch  (None, 8, 8, 256)   1024        ['conv2d_95[0][0]']
#  Normalization)
#
#  batch_normalization_135 (Batch  (None, 8, 8, 256)   1024        ['conv2d_96[0][0]']
#  Normalization)
#
#  activation_137 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_137[0][0]']
#
#  activation_138 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_138[0][0]']
#
#  activation_142 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_142[0][0]']
#
#  activation_143 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_143[0][0]']
#
#  activation_134 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_134[0][0]']
#
#  activation_135 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_135[0][0]']
#
#  concatenate_27 (Concatenate)   (None, 8, 8, 512)    0           ['activation_137[0][0]',
#                                                                   'activation_138[0][0]']
#
#  concatenate_28 (Concatenate)   (None, 8, 8, 512)    0           ['activation_142[0][0]',
#                                                                   'activation_143[0][0]']
#
#  concatenate_29 (Concatenate)   (None, 8, 8, 1536)   0           ['activation_134[0][0]',
#                                                                   'activation_135[0][0]',
#                                                                   'concatenate_27[0][0]',
#                                                                   'concatenate_28[0][0]']
#
#  average_pooling2d_11 (AverageP  (None, 1, 1, 1536)  0           ['concatenate_29[0][0]']
#  ooling2D)
#
#  dropout_2 (Dropout)            (None, 1, 1, 1536)   0           ['average_pooling2d_11[0][0]']
#
#  flatten_2 (Flatten)            (None, 1536)         0           ['dropout_2[0][0]']
#
#  dense_2 (Dense)                (None, 7)            10759       ['flatten_2[0][0]']
#
# ==================================================================================================
# Total params: 10,216,295
# Trainable params: 10,197,031
# Non-trainable params: 19,264
# __________________________________________________________________________________________________

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
# Train the model
history=model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=50,
    verbose=1,
)
# Out:
# Epoch 1/50
# 63/63 [==============================] - 77s 1s/step - loss: 0.9226 - accuracy: 0.6703 - val_loss: 1.6999 - val_accuracy: 0.4625
# Epoch 2/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7659 - accuracy: 0.7113 - val_loss: 1.5633 - val_accuracy: 0.6693
# Epoch 3/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7310 - accuracy: 0.7243 - val_loss: 1.4458 - val_accuracy: 0.6693
# Epoch 4/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.7075 - accuracy: 0.7351 - val_loss: 1.4058 - val_accuracy: 0.6693
# Epoch 5/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.6825 - accuracy: 0.7427 - val_loss: 1.3961 - val_accuracy: 0.6543
# Epoch 6/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.6637 - accuracy: 0.7527 - val_loss: 1.5317 - val_accuracy: 0.4306
# Epoch 7/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.6466 - accuracy: 0.7618 - val_loss: 1.1548 - val_accuracy: 0.6683
# Epoch 8/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.6486 - accuracy: 0.7578 - val_loss: 1.1216 - val_accuracy: 0.6533
# Epoch 9/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.6213 - accuracy: 0.7674 - val_loss: 0.8316 - val_accuracy: 0.6973
# Epoch 10/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.6188 - accuracy: 0.7666 - val_loss: 0.9104 - val_accuracy: 0.6903
# Epoch 11/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.5996 - accuracy: 0.7771 - val_loss: 0.7016 - val_accuracy: 0.7483
# Epoch 12/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.5950 - accuracy: 0.7797 - val_loss: 0.9864 - val_accuracy: 0.6673
# Epoch 13/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.5872 - accuracy: 0.7790 - val_loss: 1.1674 - val_accuracy: 0.5944
# Epoch 14/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.5698 - accuracy: 0.7861 - val_loss: 1.0967 - val_accuracy: 0.6943
# Epoch 15/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.5492 - accuracy: 0.7937 - val_loss: 0.8544 - val_accuracy: 0.7063
# Epoch 16/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.5497 - accuracy: 0.7936 - val_loss: 0.8954 - val_accuracy: 0.7023
# Epoch 17/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.5338 - accuracy: 0.7996 - val_loss: 0.9985 - val_accuracy: 0.6464
# Epoch 18/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.5350 - accuracy: 0.7997 - val_loss: 0.7803 - val_accuracy: 0.7223
# Epoch 19/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.5268 - accuracy: 0.8024 - val_loss: 1.2789 - val_accuracy: 0.6124
# Epoch 20/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.5155 - accuracy: 0.8023 - val_loss: 0.8423 - val_accuracy: 0.7033
# Epoch 21/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.5148 - accuracy: 0.8054 - val_loss: 0.7704 - val_accuracy: 0.7163
# Epoch 22/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.5032 - accuracy: 0.8086 - val_loss: 0.7596 - val_accuracy: 0.7473
# Epoch 23/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.4959 - accuracy: 0.8158 - val_loss: 0.9511 - val_accuracy: 0.7632
# Epoch 24/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.4969 - accuracy: 0.8104 - val_loss: 0.8829 - val_accuracy: 0.7213
# Epoch 25/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.4847 - accuracy: 0.8158 - val_loss: 0.7897 - val_accuracy: 0.7373
# Epoch 26/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.4675 - accuracy: 0.8242 - val_loss: 0.7457 - val_accuracy: 0.7173
# Epoch 27/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.4768 - accuracy: 0.8189 - val_loss: 0.9166 - val_accuracy: 0.6763
# Epoch 28/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.4688 - accuracy: 0.8189 - val_loss: 0.8007 - val_accuracy: 0.7183
# Epoch 29/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.4594 - accuracy: 0.8217 - val_loss: 1.2108 - val_accuracy: 0.6613
# Epoch 30/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.4420 - accuracy: 0.8267 - val_loss: 0.7616 - val_accuracy: 0.7273
# Epoch 31/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.4324 - accuracy: 0.8355 - val_loss: 1.2814 - val_accuracy: 0.6434
# Epoch 32/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.4382 - accuracy: 0.8348 - val_loss: 0.7197 - val_accuracy: 0.7253
# Epoch 33/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.4176 - accuracy: 0.8394 - val_loss: 0.7163 - val_accuracy: 0.7483
# Epoch 34/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.4149 - accuracy: 0.8434 - val_loss: 1.2046 - val_accuracy: 0.6274
# Epoch 35/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.4118 - accuracy: 0.8424 - val_loss: 0.6571 - val_accuracy: 0.7712
# Epoch 36/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.4019 - accuracy: 0.8491 - val_loss: 0.9265 - val_accuracy: 0.7283
# Epoch 37/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.3963 - accuracy: 0.8467 - val_loss: 0.7846 - val_accuracy: 0.7373
# Epoch 38/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.3976 - accuracy: 0.8487 - val_loss: 0.7626 - val_accuracy: 0.7393
# Epoch 39/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.3723 - accuracy: 0.8575 - val_loss: 0.5873 - val_accuracy: 0.7982
# Epoch 40/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.3707 - accuracy: 0.8597 - val_loss: 0.7870 - val_accuracy: 0.7293
# Epoch 41/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.3699 - accuracy: 0.8589 - val_loss: 0.6267 - val_accuracy: 0.7822
# Epoch 42/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.3617 - accuracy: 0.8635 - val_loss: 0.7998 - val_accuracy: 0.7283
# Epoch 43/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.3597 - accuracy: 0.8646 - val_loss: 0.6284 - val_accuracy: 0.7922
# Epoch 44/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.3396 - accuracy: 0.8713 - val_loss: 1.0766 - val_accuracy: 0.7333
# Epoch 45/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.3420 - accuracy: 0.8691 - val_loss: 0.6905 - val_accuracy: 0.7752
# Epoch 46/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.3376 - accuracy: 0.8711 - val_loss: 0.7860 - val_accuracy: 0.7572
# Epoch 47/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.3273 - accuracy: 0.8746 - val_loss: 0.6839 - val_accuracy: 0.7792
# Epoch 48/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.3137 - accuracy: 0.8814 - val_loss: 0.9844 - val_accuracy: 0.6923
# Epoch 49/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.3213 - accuracy: 0.8784 - val_loss: 0.6361 - val_accuracy: 0.8012
# Epoch 50/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.2937 - accuracy: 0.8877 - val_loss: 0.7516 - val_accuracy: 0.7652

# %%
plot_training_history(history)

# %%
evaluate_model(model, 'HAM10000/test')
# Out:
# Found 1001 images belonging to 7 classes.
# 8/8 [==============================] - 4s 406ms/step
# Confusion Matrix:
# [[ 19   7   3   1   1   1   0]
#  [  4  31   7   1   1   4   4]
#  [  8   3  53   0  19  24   3]
#  [  2   3   2   2   1   1   0]
#  [ 10   4   7   0  66  23   2]
#  [ 13   6  25   0  54 566   6]
#  [  0   0   0   0   0   0  14]]
# Classification Report:
#               precision    recall  f1-score   support
#
#        akiec       0.34      0.59      0.43        32
#          bcc       0.57      0.60      0.58        52
#          bkl       0.55      0.48      0.51       110
#           df       0.50      0.18      0.27        11
#          mel       0.46      0.59      0.52       112
#           nv       0.91      0.84      0.88       670
#         vasc       0.48      1.00      0.65        14
#
#     accuracy                           0.75      1001
#    macro avg       0.55      0.61      0.55      1001
# weighted avg       0.78      0.75      0.76      1001

# %%
import tensorflow as tf

from tensorflow.keras import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.optimizers import Adam

# Load data
inputs=tf.keras.Input(shape=(299, 299, 3))
outputs=DS_inception_Model(inputs)
model=tf.keras.Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d_99 (Conv2D)             (None, 149, 149, 32  896         ['input_4[0][0]']
#                                 )
#
#  batch_normalization_144 (Batch  (None, 149, 149, 32  128        ['conv2d_99[0][0]']
#  Normalization)                 )
#
#  activation_144 (Activation)    (None, 149, 149, 32  0           ['batch_normalization_144[0][0]']
#                                 )
#
#  conv2d_100 (Conv2D)            (None, 147, 147, 32  9248        ['activation_144[0][0]']
#                                 )
#
#  batch_normalization_145 (Batch  (None, 147, 147, 32  128        ['conv2d_100[0][0]']
#  Normalization)                 )
#
#  activation_145 (Activation)    (None, 147, 147, 32  0           ['batch_normalization_145[0][0]']
#                                 )
#
#  conv2d_101 (Conv2D)            (None, 147, 147, 64  18496       ['activation_145[0][0]']
#                                 )
#
#  batch_normalization_146 (Batch  (None, 147, 147, 64  256        ['conv2d_101[0][0]']
#  Normalization)                 )
#
#  activation_146 (Activation)    (None, 147, 147, 64  0           ['batch_normalization_146[0][0]']
#                                 )
#
#  conv2d_102 (Conv2D)            (None, 73, 73, 96)   55392       ['activation_146[0][0]']
#
#  batch_normalization_147 (Batch  (None, 73, 73, 96)  384         ['conv2d_102[0][0]']
#  Normalization)
#
#  max_pooling2d_12 (MaxPooling2D  (None, 73, 73, 64)  0           ['activation_146[0][0]']
#  )
#
#  activation_147 (Activation)    (None, 73, 73, 96)   0           ['batch_normalization_147[0][0]']
#
#  concatenate_30 (Concatenate)   (None, 73, 73, 160)  0           ['max_pooling2d_12[0][0]',
#                                                                   'activation_147[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 73, 73, 64)   10304       ['concatenate_30[0][0]']
#
#  batch_normalization_150 (Batch  (None, 73, 73, 64)  256         ['conv2d_105[0][0]']
#  Normalization)
#
#  activation_150 (Activation)    (None, 73, 73, 64)   0           ['batch_normalization_150[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 73, 73, 64)   28736       ['activation_150[0][0]']
#
#  batch_normalization_151 (Batch  (None, 73, 73, 64)  256         ['conv2d_106[0][0]']
#  Normalization)
#
#  activation_151 (Activation)    (None, 73, 73, 64)   0           ['batch_normalization_151[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 73, 73, 64)   10304       ['concatenate_30[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 73, 73, 64)   28736       ['activation_151[0][0]']
#
#  batch_normalization_148 (Batch  (None, 73, 73, 64)  256         ['conv2d_103[0][0]']
#  Normalization)
#
#  batch_normalization_152 (Batch  (None, 73, 73, 64)  256         ['conv2d_107[0][0]']
#  Normalization)
#
#  activation_148 (Activation)    (None, 73, 73, 64)   0           ['batch_normalization_148[0][0]']
#
#  activation_152 (Activation)    (None, 73, 73, 64)   0           ['batch_normalization_152[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 71, 71, 96)   55392       ['activation_148[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 71, 71, 96)   55392       ['activation_152[0][0]']
#
#  batch_normalization_149 (Batch  (None, 71, 71, 96)  384         ['conv2d_104[0][0]']
#  Normalization)
#
#  batch_normalization_153 (Batch  (None, 71, 71, 96)  384         ['conv2d_108[0][0]']
#  Normalization)
#
#  activation_149 (Activation)    (None, 71, 71, 96)   0           ['batch_normalization_149[0][0]']
#
#  activation_153 (Activation)    (None, 71, 71, 96)   0           ['batch_normalization_153[0][0]']
#
#  concatenate_31 (Concatenate)   (None, 71, 71, 192)  0           ['activation_149[0][0]',
#                                                                   'activation_153[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 35, 35, 192)  331968      ['concatenate_31[0][0]']
#
#  batch_normalization_154 (Batch  (None, 35, 35, 192)  768        ['conv2d_109[0][0]']
#  Normalization)
#
#  activation_154 (Activation)    (None, 35, 35, 192)  0           ['batch_normalization_154[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 35, 35, 192)  0          ['concatenate_31[0][0]']
#  )
#
#  concatenate_32 (Concatenate)   (None, 35, 35, 384)  0           ['activation_154[0][0]',
#                                                                   'max_pooling2d_13[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 35, 35, 64)   24640       ['concatenate_32[0][0]']
#
#  batch_normalization_159 (Batch  (None, 35, 35, 64)  256         ['conv2d_113[0][0]']
#  Normalization)
#
#  activation_159 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_159[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 35, 35, 96)   331872      ['concatenate_32[0][0]']
#
#  separable_conv2d_46 (Separable  (None, 35, 35, 96)  6816        ['activation_159[0][0]']
#  Conv2D)
#
#  batch_normalization_157 (Batch  (None, 35, 35, 96)  384         ['conv2d_112[0][0]']
#  Normalization)
#
#  batch_normalization_160 (Batch  (None, 35, 35, 96)  384         ['separable_conv2d_46[0][0]']
#  Normalization)
#
#  average_pooling2d_12 (AverageP  (None, 35, 35, 384)  0          ['concatenate_32[0][0]']
#  ooling2D)
#
#  activation_157 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_157[0][0]']
#
#  activation_160 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_160[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 35, 35, 96)   36960       ['average_pooling2d_12[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 35, 35, 96)   36960       ['concatenate_32[0][0]']
#
#  separable_conv2d_45 (Separable  (None, 35, 35, 96)  10176       ['activation_157[0][0]']
#  Conv2D)
#
#  separable_conv2d_47 (Separable  (None, 35, 35, 96)  10176       ['activation_160[0][0]']
#  Conv2D)
#
#  batch_normalization_155 (Batch  (None, 35, 35, 96)  384         ['conv2d_110[0][0]']
#  Normalization)
#
#  batch_normalization_156 (Batch  (None, 35, 35, 96)  384         ['conv2d_111[0][0]']
#  Normalization)
#
#  batch_normalization_158 (Batch  (None, 35, 35, 96)  384         ['separable_conv2d_45[0][0]']
#  Normalization)
#
#  batch_normalization_161 (Batch  (None, 35, 35, 96)  384         ['separable_conv2d_47[0][0]']
#  Normalization)
#
#  activation_155 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_155[0][0]']
#
#  activation_156 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_156[0][0]']
#
#  activation_158 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_158[0][0]']
#
#  activation_161 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_161[0][0]']
#
#  concatenate_33 (Concatenate)   (None, 35, 35, 384)  0           ['activation_155[0][0]',
#                                                                   'activation_156[0][0]',
#                                                                   'activation_158[0][0]',
#                                                                   'activation_161[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 35, 35, 192)  73920       ['concatenate_33[0][0]']
#
#  batch_normalization_163 (Batch  (None, 35, 35, 192)  768        ['conv2d_115[0][0]']
#  Normalization)
#
#  activation_163 (Activation)    (None, 35, 35, 192)  0           ['batch_normalization_163[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 35, 35, 224)  387296      ['activation_163[0][0]']
#
#  batch_normalization_164 (Batch  (None, 35, 35, 224)  896        ['conv2d_116[0][0]']
#  Normalization)
#
#  activation_164 (Activation)    (None, 35, 35, 224)  0           ['batch_normalization_164[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 17, 17, 384)  1327488     ['concatenate_33[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 17, 17, 256)  516352      ['activation_164[0][0]']
#
#  batch_normalization_162 (Batch  (None, 17, 17, 384)  1536       ['conv2d_114[0][0]']
#  Normalization)
#
#  batch_normalization_165 (Batch  (None, 17, 17, 256)  1024       ['conv2d_117[0][0]']
#  Normalization)
#
#  max_pooling2d_14 (MaxPooling2D  (None, 17, 17, 384)  0          ['concatenate_33[0][0]']
#  )
#
#  activation_162 (Activation)    (None, 17, 17, 384)  0           ['batch_normalization_162[0][0]']
#
#  activation_165 (Activation)    (None, 17, 17, 256)  0           ['batch_normalization_165[0][0]']
#
#  concatenate_34 (Concatenate)   (None, 17, 17, 1024  0           ['max_pooling2d_14[0][0]',
#                                 )                                 'activation_162[0][0]',
#                                                                   'activation_165[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 17, 17, 192)  196800      ['concatenate_34[0][0]']
#
#  batch_normalization_171 (Batch  (None, 17, 17, 192)  768        ['conv2d_121[0][0]']
#  Normalization)
#
#  activation_171 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_171[0][0]']
#
#  separable_conv2d_50 (Separable  (None, 17, 17, 192)  38400      ['activation_171[0][0]']
#  Conv2D)
#
#  batch_normalization_172 (Batch  (None, 17, 17, 192)  768        ['separable_conv2d_50[0][0]']
#  Normalization)
#
#  activation_172 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_172[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 17, 17, 192)  196800      ['concatenate_34[0][0]']
#
#  separable_conv2d_51 (Separable  (None, 17, 17, 224)  44576      ['activation_172[0][0]']
#  Conv2D)
#
#  batch_normalization_168 (Batch  (None, 17, 17, 192)  768        ['conv2d_120[0][0]']
#  Normalization)
#
#  batch_normalization_173 (Batch  (None, 17, 17, 224)  896        ['separable_conv2d_51[0][0]']
#  Normalization)
#
#  activation_168 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_168[0][0]']
#
#  activation_173 (Activation)    (None, 17, 17, 224)  0           ['batch_normalization_173[0][0]']
#
#  separable_conv2d_48 (Separable  (None, 17, 17, 224)  44576      ['activation_168[0][0]']
#  Conv2D)
#
#  separable_conv2d_52 (Separable  (None, 17, 17, 224)  51968      ['activation_173[0][0]']
#  Conv2D)
#
#  batch_normalization_169 (Batch  (None, 17, 17, 224)  896        ['separable_conv2d_48[0][0]']
#  Normalization)
#
#  batch_normalization_174 (Batch  (None, 17, 17, 224)  896        ['separable_conv2d_52[0][0]']
#  Normalization)
#
#  activation_169 (Activation)    (None, 17, 17, 224)  0           ['batch_normalization_169[0][0]']
#
#  activation_174 (Activation)    (None, 17, 17, 224)  0           ['batch_normalization_174[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 17, 17, 128)  131200      ['concatenate_34[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 17, 17, 384)  393600      ['concatenate_34[0][0]']
#
#  separable_conv2d_49 (Separable  (None, 17, 17, 256)  59168      ['activation_169[0][0]']
#  Conv2D)
#
#  separable_conv2d_53 (Separable  (None, 17, 17, 256)  59168      ['activation_174[0][0]']
#  Conv2D)
#
#  batch_normalization_166 (Batch  (None, 17, 17, 128)  512        ['conv2d_118[0][0]']
#  Normalization)
#
#  batch_normalization_167 (Batch  (None, 17, 17, 384)  1536       ['conv2d_119[0][0]']
#  Normalization)
#
#  batch_normalization_170 (Batch  (None, 17, 17, 256)  1024       ['separable_conv2d_49[0][0]']
#  Normalization)
#
#  batch_normalization_175 (Batch  (None, 17, 17, 256)  1024       ['separable_conv2d_53[0][0]']
#  Normalization)
#
#  activation_166 (Activation)    (None, 17, 17, 128)  0           ['batch_normalization_166[0][0]']
#
#  activation_167 (Activation)    (None, 17, 17, 384)  0           ['batch_normalization_167[0][0]']
#
#  activation_170 (Activation)    (None, 17, 17, 256)  0           ['batch_normalization_170[0][0]']
#
#  activation_175 (Activation)    (None, 17, 17, 256)  0           ['batch_normalization_175[0][0]']
#
#  concatenate_35 (Concatenate)   (None, 17, 17, 1024  0           ['activation_166[0][0]',
#                                 )                                 'activation_167[0][0]',
#                                                                   'activation_170[0][0]',
#                                                                   'activation_175[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 17, 17, 256)  262400      ['concatenate_35[0][0]']
#
#  batch_normalization_178 (Batch  (None, 17, 17, 256)  1024       ['conv2d_124[0][0]']
#  Normalization)
#
#  activation_178 (Activation)    (None, 17, 17, 256)  0           ['batch_normalization_178[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 17, 17, 256)  459008      ['activation_178[0][0]']
#
#  batch_normalization_179 (Batch  (None, 17, 17, 256)  1024       ['conv2d_125[0][0]']
#  Normalization)
#
#  activation_179 (Activation)    (None, 17, 17, 256)  0           ['batch_normalization_179[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 17, 17, 192)  196800      ['concatenate_35[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 17, 17, 320)  573760      ['activation_179[0][0]']
#
#  batch_normalization_176 (Batch  (None, 17, 17, 192)  768        ['conv2d_122[0][0]']
#  Normalization)
#
#  batch_normalization_180 (Batch  (None, 17, 17, 320)  1280       ['conv2d_126[0][0]']
#  Normalization)
#
#  activation_176 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_176[0][0]']
#
#  activation_180 (Activation)    (None, 17, 17, 320)  0           ['batch_normalization_180[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 8, 8, 192)    331968      ['activation_176[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 8, 8, 320)    921920      ['activation_180[0][0]']
#
#  batch_normalization_177 (Batch  (None, 8, 8, 192)   768         ['conv2d_123[0][0]']
#  Normalization)
#
#  batch_normalization_181 (Batch  (None, 8, 8, 320)   1280        ['conv2d_127[0][0]']
#  Normalization)
#
#  max_pooling2d_15 (MaxPooling2D  (None, 8, 8, 1024)  0           ['concatenate_35[0][0]']
#  )
#
#  activation_177 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_177[0][0]']
#
#  activation_181 (Activation)    (None, 8, 8, 320)    0           ['batch_normalization_181[0][0]']
#
#  concatenate_36 (Concatenate)   (None, 8, 8, 1536)   0           ['max_pooling2d_15[0][0]',
#                                                                   'activation_177[0][0]',
#                                                                   'activation_181[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 8, 8, 384)    590208      ['concatenate_36[0][0]']
#
#  batch_normalization_187 (Batch  (None, 8, 8, 384)   1536        ['conv2d_131[0][0]']
#  Normalization)
#
#  activation_187 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_187[0][0]']
#
#  separable_conv2d_56 (Separable  (None, 8, 8, 448)   173632      ['activation_187[0][0]']
#  Conv2D)
#
#  batch_normalization_188 (Batch  (None, 8, 8, 448)   1792        ['separable_conv2d_56[0][0]']
#  Normalization)
#
#  activation_188 (Activation)    (None, 8, 8, 448)    0           ['batch_normalization_188[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 8, 8, 384)    590208      ['concatenate_36[0][0]']
#
#  separable_conv2d_57 (Separable  (None, 8, 8, 512)   231232      ['activation_188[0][0]']
#  Conv2D)
#
#  batch_normalization_184 (Batch  (None, 8, 8, 384)   1536        ['conv2d_130[0][0]']
#  Normalization)
#
#  batch_normalization_189 (Batch  (None, 8, 8, 512)   2048        ['separable_conv2d_57[0][0]']
#  Normalization)
#
#  activation_184 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_184[0][0]']
#
#  activation_189 (Activation)    (None, 8, 8, 512)    0           ['batch_normalization_189[0][0]']
#
#  average_pooling2d_14 (AverageP  (None, 8, 8, 1536)  0           ['concatenate_36[0][0]']
#  ooling2D)
#
#  separable_conv2d_54 (Separable  (None, 8, 8, 256)   99712       ['activation_184[0][0]']
#  Conv2D)
#
#  separable_conv2d_55 (Separable  (None, 8, 8, 256)   99712       ['activation_184[0][0]']
#  Conv2D)
#
#  separable_conv2d_58 (Separable  (None, 8, 8, 256)   132864      ['activation_189[0][0]']
#  Conv2D)
#
#  separable_conv2d_59 (Separable  (None, 8, 8, 256)   132864      ['activation_189[0][0]']
#  Conv2D)
#
#  conv2d_128 (Conv2D)            (None, 8, 8, 256)    393472      ['average_pooling2d_14[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 8, 8, 256)    393472      ['concatenate_36[0][0]']
#
#  batch_normalization_185 (Batch  (None, 8, 8, 256)   1024        ['separable_conv2d_54[0][0]']
#  Normalization)
#
#  batch_normalization_186 (Batch  (None, 8, 8, 256)   1024        ['separable_conv2d_55[0][0]']
#  Normalization)
#
#  batch_normalization_190 (Batch  (None, 8, 8, 256)   1024        ['separable_conv2d_58[0][0]']
#  Normalization)
#
#  batch_normalization_191 (Batch  (None, 8, 8, 256)   1024        ['separable_conv2d_59[0][0]']
#  Normalization)
#
#  batch_normalization_182 (Batch  (None, 8, 8, 256)   1024        ['conv2d_128[0][0]']
#  Normalization)
#
#  batch_normalization_183 (Batch  (None, 8, 8, 256)   1024        ['conv2d_129[0][0]']
#  Normalization)
#
#  activation_185 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_185[0][0]']
#
#  activation_186 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_186[0][0]']
#
#  activation_190 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_190[0][0]']
#
#  activation_191 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_191[0][0]']
#
#  activation_182 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_182[0][0]']
#
#  activation_183 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_183[0][0]']
#
#  concatenate_37 (Concatenate)   (None, 8, 8, 512)    0           ['activation_185[0][0]',
#                                                                   'activation_186[0][0]']
#
#  concatenate_38 (Concatenate)   (None, 8, 8, 512)    0           ['activation_190[0][0]',
#                                                                   'activation_191[0][0]']
#
#  concatenate_39 (Concatenate)   (None, 8, 8, 1536)   0           ['activation_182[0][0]',
#                                                                   'activation_183[0][0]',
#                                                                   'concatenate_37[0][0]',
#                                                                   'concatenate_38[0][0]']
#
#  average_pooling2d_15 (AverageP  (None, 1, 1, 1536)  0           ['concatenate_39[0][0]']
#  ooling2D)
#
#  dropout_3 (Dropout)            (None, 1, 1, 1536)   0           ['average_pooling2d_15[0][0]']
#
#  flatten_3 (Flatten)            (None, 1536)         0           ['dropout_3[0][0]']
#
#  dense_3 (Dense)                (None, 7)            10759       ['flatten_3[0][0]']
#
# ==================================================================================================
# Total params: 10,216,295
# Trainable params: 10,197,031
# Non-trainable params: 19,264
# __________________________________________________________________________________________________

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
# Train the model
history=model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=50,
    verbose=1
)
# Out:
# Epoch 1/50
# 63/63 [==============================] - 77s 1s/step - loss: 0.9275 - accuracy: 0.6663 - val_loss: 1.8325 - val_accuracy: 0.5085
# Epoch 2/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.7510 - accuracy: 0.7153 - val_loss: 1.7335 - val_accuracy: 0.6693
# Epoch 3/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.7093 - accuracy: 0.7329 - val_loss: 1.6210 - val_accuracy: 0.6693
# Epoch 4/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.6689 - accuracy: 0.7518 - val_loss: 1.5031 - val_accuracy: 0.6693
# Epoch 5/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.6607 - accuracy: 0.7494 - val_loss: 1.7402 - val_accuracy: 0.6354
# Epoch 6/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.6274 - accuracy: 0.7674 - val_loss: 1.5941 - val_accuracy: 0.6304
# Epoch 7/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.6188 - accuracy: 0.7669 - val_loss: 1.5057 - val_accuracy: 0.5534
# Epoch 8/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.5949 - accuracy: 0.7739 - val_loss: 1.2330 - val_accuracy: 0.6474
# Epoch 9/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.5720 - accuracy: 0.7901 - val_loss: 1.1176 - val_accuracy: 0.6434
# Epoch 10/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.5688 - accuracy: 0.7866 - val_loss: 0.8504 - val_accuracy: 0.7043
# Epoch 11/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.5508 - accuracy: 0.7908 - val_loss: 0.7130 - val_accuracy: 0.7473
# Epoch 12/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.5440 - accuracy: 0.7932 - val_loss: 0.6882 - val_accuracy: 0.7552
# Epoch 13/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.5241 - accuracy: 0.7987 - val_loss: 0.6941 - val_accuracy: 0.7602
# Epoch 14/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.5296 - accuracy: 0.7986 - val_loss: 0.6896 - val_accuracy: 0.7602
# Epoch 15/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.5086 - accuracy: 0.8027 - val_loss: 0.7226 - val_accuracy: 0.7353
# Epoch 16/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.4957 - accuracy: 0.8104 - val_loss: 0.6891 - val_accuracy: 0.7602
# Epoch 17/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.4920 - accuracy: 0.8143 - val_loss: 0.6980 - val_accuracy: 0.7502
# Epoch 18/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.4709 - accuracy: 0.8190 - val_loss: 0.7077 - val_accuracy: 0.7612
# Epoch 19/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.4667 - accuracy: 0.8197 - val_loss: 0.7007 - val_accuracy: 0.7612
# Epoch 20/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.4487 - accuracy: 0.8264 - val_loss: 0.6650 - val_accuracy: 0.7732
# Epoch 21/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.4398 - accuracy: 0.8328 - val_loss: 0.7152 - val_accuracy: 0.7493
# Epoch 22/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.4289 - accuracy: 0.8369 - val_loss: 0.7092 - val_accuracy: 0.7732
# Epoch 23/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.4172 - accuracy: 0.8430 - val_loss: 0.7479 - val_accuracy: 0.7502
# Epoch 24/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.4145 - accuracy: 0.8421 - val_loss: 0.7396 - val_accuracy: 0.7283
# Epoch 25/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.3979 - accuracy: 0.8453 - val_loss: 0.7524 - val_accuracy: 0.7572
# Epoch 26/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.3903 - accuracy: 0.8500 - val_loss: 0.7482 - val_accuracy: 0.7483
# Epoch 27/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.3895 - accuracy: 0.8511 - val_loss: 0.7821 - val_accuracy: 0.7562
# Epoch 28/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.3689 - accuracy: 0.8589 - val_loss: 0.6938 - val_accuracy: 0.7652
# Epoch 29/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.3687 - accuracy: 0.8601 - val_loss: 0.8029 - val_accuracy: 0.7622
# Epoch 30/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.3709 - accuracy: 0.8567 - val_loss: 0.7343 - val_accuracy: 0.7502
# Epoch 31/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.3650 - accuracy: 0.8632 - val_loss: 0.7463 - val_accuracy: 0.7642
# Epoch 32/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.3266 - accuracy: 0.8728 - val_loss: 0.8656 - val_accuracy: 0.7552
# Epoch 33/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.3224 - accuracy: 0.8782 - val_loss: 0.8031 - val_accuracy: 0.7582
# Epoch 34/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.3196 - accuracy: 0.8761 - val_loss: 0.9048 - val_accuracy: 0.7393
# Epoch 35/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.3389 - accuracy: 0.8696 - val_loss: 0.8345 - val_accuracy: 0.7562
# Epoch 36/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.3058 - accuracy: 0.8834 - val_loss: 0.7914 - val_accuracy: 0.7702
# Epoch 37/50
# 63/63 [==============================] - 75s 1s/step - loss: 0.2981 - accuracy: 0.8859 - val_loss: 0.8682 - val_accuracy: 0.7602
# Epoch 38/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.2953 - accuracy: 0.8872 - val_loss: 0.9557 - val_accuracy: 0.7483
# Epoch 39/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.2888 - accuracy: 0.8921 - val_loss: 0.8463 - val_accuracy: 0.7832
# Epoch 40/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.2833 - accuracy: 0.8899 - val_loss: 0.7759 - val_accuracy: 0.7582
# Epoch 41/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.2604 - accuracy: 0.9027 - val_loss: 0.8669 - val_accuracy: 0.7632
# Epoch 42/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.2682 - accuracy: 0.8982 - val_loss: 0.8268 - val_accuracy: 0.7752
# Epoch 43/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.2459 - accuracy: 0.9042 - val_loss: 0.9022 - val_accuracy: 0.7702
# Epoch 44/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.2567 - accuracy: 0.9025 - val_loss: 0.9353 - val_accuracy: 0.7592
# Epoch 45/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.2465 - accuracy: 0.9052 - val_loss: 0.8737 - val_accuracy: 0.7373
# Epoch 46/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.2485 - accuracy: 0.9084 - val_loss: 0.8988 - val_accuracy: 0.7602
# Epoch 47/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.2240 - accuracy: 0.9183 - val_loss: 0.8334 - val_accuracy: 0.7772
# Epoch 48/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.2207 - accuracy: 0.9169 - val_loss: 0.8857 - val_accuracy: 0.7662
# Epoch 49/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.2067 - accuracy: 0.9219 - val_loss: 0.9200 - val_accuracy: 0.7872
# Epoch 50/50
# 63/63 [==============================] - 74s 1s/step - loss: 0.2164 - accuracy: 0.9180 - val_loss: 0.8282 - val_accuracy: 0.7802

# %%
plot_training_history(history)

# %%
evaluate_model(model, 'HAM10000/test')
# Out:
# Found 1001 images belonging to 7 classes.
# 8/8 [==============================] - 4s 414ms/step
# Confusion Matrix:
# [[  7  10   7   2   4   2   0]
#  [  0  37   3   0   3   8   1]
#  [  0   6  56   0  12  36   0]
#  [  1   2   2   2   2   2   0]
#  [  1   3  24   0  57  27   0]
#  [  3   8  24   2  33 598   2]
#  [  0   0   0   0   0   2  12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#        akiec       0.58      0.22      0.32        32
#          bcc       0.56      0.71      0.63        52
#          bkl       0.48      0.51      0.50       110
#           df       0.33      0.18      0.24        11
#          mel       0.51      0.51      0.51       112
#           nv       0.89      0.89      0.89       670
#         vasc       0.80      0.86      0.83        14
#
#     accuracy                           0.77      1001
#    macro avg       0.59      0.55      0.56      1001
# weighted avg       0.77      0.77      0.76      1001
